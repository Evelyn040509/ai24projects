# %% [markdown]
# # 人工智能引论大作业——遥感图像土地利用分类
# ## 2022202799
# ## Segment anything2 模型微调

# %%
import numpy as np
import torch
import cv2
import os
from sam2.build_sam import build_sam2
from sam2.sam2_image_predictor import SAM2ImagePredictor

# %%
# import data
os.chdir(r"D:\code\PycharmProjects\sam2-main")

data_dir=r"./EarthVQA/" # Path to dataset
data=[] # list of files in dataset
for ff, name in enumerate(os.listdir(data_dir+"Train/images_png/")):  # go over all folder annotation
    data.append({"image":data_dir+"Train/images_png/"+name,
                 "annotation":data_dir+"Train/masks_png/"+name})

# %%
def read_batch(data): # read random image and its annotaion from the dataset

   #  select image

        ent  = data[np.random.randint(len(data))] # choose random entry
        Img = cv2.imread(ent["image"])[...,::-1]  # read image
        ann_map = cv2.imread(ent["annotation"]) # read annotation

   # resize image

        r = np.min([1024 / Img.shape[1], 1024 / Img.shape[0]]) # scalling factor
        Img = cv2.resize(Img, (int(Img.shape[1] * r), int(Img.shape[0] * r)))
        ann_map = cv2.resize(ann_map, (int(ann_map.shape[1] * r), int(ann_map.shape[0] * r)),interpolation=cv2.INTER_NEAREST)

   # merge vessels and materials annotations

        mat_map = ann_map[:,:,0] # material annotation map
        ves_map = ann_map[:,:,2] # vessel  annotaion map
        mat_map[mat_map==0] = ves_map[mat_map==0]*(mat_map.max()+1) # merge maps

   # Get binary masks and points

        inds = np.unique(mat_map)[1:] # load all indices
        points= []
        masks = []
        for ind in inds:
            mask=(mat_map == ind).astype(np.uint8) # make binary mask corresponding to index ind
            masks.append(mask)
            coords = np.argwhere(mask > 0) # get all coordinates in mask
            yx = np.array(coords[np.random.randint(len(coords))]) # choose random point/coordinate
            points.append([[yx[1], yx[0]]])
        return Img,np.array(masks),np.array(points), np.ones([len(masks),1])

# %%
# Load model

sam2_checkpoint = "./checkpoints/sam2.1_hiera_large.pt" # path to model weight
model_cfg = "configs/sam2.1/sam2.1_hiera_l.yaml" #  model config
sam2_model = build_sam2(model_cfg, sam2_checkpoint, device="cuda") # load model
predictor = SAM2ImagePredictor(sam2_model)

# %%
# Set training parameters

predictor.model.sam_mask_decoder.train(True) # enable training of mask decoder
predictor.model.sam_prompt_encoder.train(True) # enable training of prompt encoder

optimizer=torch.optim.AdamW(params=predictor.model.parameters(),lr=1e-5,weight_decay=4e-5)
scaler = torch.cuda.amp.GradScaler() # mixed precision

# %%
# Training loop

for itr in range(100000):
    with torch.cuda.amp.autocast(): # cast to mix precision
            image,mask,input_point, input_label = read_batch(data) # load data batch
            if mask.shape[0]==0: continue # ignore empty batches
            predictor.set_image(image) # apply SAM image encoder to the image

            # prompt encoding

            mask_input, unnorm_coords, labels, unnorm_box = predictor._prep_prompts(input_point, input_label, box=None, mask_logits=None, normalize_coords=True)
            sparse_embeddings, dense_embeddings = predictor.model.sam_prompt_encoder(points=(unnorm_coords, labels),boxes=None,masks=None,)

            # mask decoder

            batched_mode = unnorm_coords.shape[0] > 1 # multi object prediction
            high_res_features = [feat_level[-1].unsqueeze(0) for feat_level in predictor._features["high_res_feats"]]
            low_res_masks, prd_scores, _, _ = predictor.model.sam_mask_decoder(image_embeddings=predictor._features["image_embed"][-1].unsqueeze(0),image_pe=predictor.model.sam_prompt_encoder.get_dense_pe(),sparse_prompt_embeddings=sparse_embeddings,dense_prompt_embeddings=dense_embeddings,multimask_output=True,repeat_image=batched_mode,high_res_features=high_res_features,)
            prd_masks = predictor._transforms.postprocess_masks(low_res_masks, predictor._orig_hw[-1])# Upscale the masks to the original image resolution

            # Segmentaion Loss caclulation

            gt_mask = torch.tensor(mask.astype(np.float32)).cuda()
            prd_mask = torch.sigmoid(prd_masks[:, 0])# Turn logit map to probability map
            seg_loss = (-gt_mask * torch.log(prd_mask + 0.00001) - (1 - gt_mask) * torch.log((1 - prd_mask) + 0.00001)).mean() # cross entropy loss

            # Score loss calculation (intersection over union) IOU

            inter = (gt_mask * (prd_mask > 0.5)).sum(1).sum(1)
            iou = inter / (gt_mask.sum(1).sum(1) + (prd_mask > 0.5).sum(1).sum(1) - inter)
            score_loss = torch.abs(prd_scores[:, 0] - iou).mean()
            loss=seg_loss+score_loss*0.05  # mix losses

            # apply back propogation

            predictor.model.zero_grad() # empty gradient
            scaler.scale(loss).backward()  # Backpropogate
            scaler.step(optimizer)
            scaler.update() # Mix precision

            if itr%1000==0: torch.save(predictor.model.state_dict(), "model.torch");print("save model")

            # Display results

            if itr==0: mean_iou=0
            mean_iou = mean_iou * 0.99 + 0.01 * np.mean(iou.cpu().detach().numpy())
            print("step)",itr, "Accuracy(IOU)=",mean_iou)
# Out:
# D:\applications\anaconda3\envs\seganything\Lib\site-packages\torch\autograd\graph.py:825: UserWarning: cuDNN SDPA backward got grad_output.strides() != output.strides(), attempting to materialize a grad_output with matching strides... (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\MHA.cpp:676.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# save model
# step) 0 Accuracy(IOU)= 0.00066666474
# step) 1 Accuracy(IOU)= 0.0013874621
# step) 2 Accuracy(IOU)= 0.0037887245
# step) 3 Accuracy(IOU)= 0.0058535044
# step) 4 Accuracy(IOU)= 0.010201282
# step) 5 Accuracy(IOU)= 0.012760536
# step) 6 Accuracy(IOU)= 0.014526149
# step) 7 Accuracy(IOU)= 0.016423756
# step) 8 Accuracy(IOU)= 0.019254299
# step) 9 Accuracy(IOU)= 0.021770991
# step) 10 Accuracy(IOU)= 0.022022925
# step) 11 Accuracy(IOU)= 0.023426756
# step) 12 Accuracy(IOU)= 0.025254127
# step) 13 Accuracy(IOU)= 0.026426636
# step) 14 Accuracy(IOU)= 0.029580858
# step) 15 Accuracy(IOU)= 0.03097155
# step) 16 Accuracy(IOU)= 0.0372687
# step) 17 Accuracy(IOU)= 0.038772844
# step) 18 Accuracy(IOU)= 0.040142063
# step) 19 Accuracy(IOU)= 0.040716615
# step) 20 Accuracy(IOU)= 0.042947248
# step) 21 Accuracy(IOU)= 0.04488991
# step) 22 Accuracy(IOU)= 0.045670144
# step) 23 Accuracy(IOU)= 0.045443032
# step) 24 Accuracy(IOU)= 0.046638425
# step) 25 Accuracy(IOU)= 0.04660449
# step) 26 Accuracy(IOU)= 0.0469492
# step) 27 Accuracy(IOU)= 0.048525617
# step) 28 Accuracy(IOU)= 0.049653377
# step) 29 Accuracy(IOU)= 0.05169564
# step) 30 Accuracy(IOU)= 0.053424526
# step) 31 Accuracy(IOU)= 0.054686993
# step) 32 Accuracy(IOU)= 0.05640145
# step) 33 Accuracy(IOU)= 0.057733953
# step) 34 Accuracy(IOU)= 0.06126668
# step) 35 Accuracy(IOU)= 0.06876909
# step) 36 Accuracy(IOU)= 0.06984235
# step) 37 Accuracy(IOU)= 0.071763225
# step) 38 Accuracy(IOU)= 0.07218536
# step) 39 Accuracy(IOU)= 0.07201271
# step) 40 Accuracy(IOU)= 0.0726475
# step) 41 Accuracy(IOU)= 0.074055925
# step) 42 Accuracy(IOU)= 0.07520473
# step) 43 Accuracy(IOU)= 0.07700291
# step) 44 Accuracy(IOU)= 0.07978994
# step) 45 Accuracy(IOU)= 0.08046919
# step) 46 Accuracy(IOU)= 0.08153808
# step) 47 Accuracy(IOU)= 0.08270909
# step) 48 Accuracy(IOU)= 0.08385096
# step) 49 Accuracy(IOU)= 0.086263336
# step) 50 Accuracy(IOU)= 0.088194974
# step) 51 Accuracy(IOU)= 0.08883599
# step) 52 Accuracy(IOU)= 0.09062693
# step) 53 Accuracy(IOU)= 0.09127602
# step) 54 Accuracy(IOU)= 0.09325785
# step) 55 Accuracy(IOU)= 0.09317723
# step) 56 Accuracy(IOU)= 0.09293832
# step) 57 Accuracy(IOU)= 0.09459215
# step) 58 Accuracy(IOU)= 0.09665151
# step) 59 Accuracy(IOU)= 0.09603274
# step) 60 Accuracy(IOU)= 0.0981675
# step) 61 Accuracy(IOU)= 0.09758064
# step) 62 Accuracy(IOU)= 0.09719434
# step) 63 Accuracy(IOU)= 0.09925909
# step) 64 Accuracy(IOU)= 0.101481155
# step) 65 Accuracy(IOU)= 0.102655336
# step) 66 Accuracy(IOU)= 0.10307072
# step) 67 Accuracy(IOU)= 0.10444073
# step) 68 Accuracy(IOU)= 0.103954256
# step) 69 Accuracy(IOU)= 0.103053294
# step) 70 Accuracy(IOU)= 0.10454193
# step) 71 Accuracy(IOU)= 0.10692535
# step) 72 Accuracy(IOU)= 0.10901398
# step) 73 Accuracy(IOU)= 0.10910926
# step) 74 Accuracy(IOU)= 0.110110804
# step) 75 Accuracy(IOU)= 0.10978885
# step) 76 Accuracy(IOU)= 0.11159736
# step) 77 Accuracy(IOU)= 0.11227262
# step) 78 Accuracy(IOU)= 0.114279464
# step) 79 Accuracy(IOU)= 0.1145948
# step) 80 Accuracy(IOU)= 0.11583917
# step) 81 Accuracy(IOU)= 0.1165714
# step) 82 Accuracy(IOU)= 0.11838275
# step) 83 Accuracy(IOU)= 0.1194218
# step) 84 Accuracy(IOU)= 0.11887015
# step) 85 Accuracy(IOU)= 0.12225752
# step) 86 Accuracy(IOU)= 0.12217023
# step) 87 Accuracy(IOU)= 0.12377513
# step) 88 Accuracy(IOU)= 0.12677583
# step) 89 Accuracy(IOU)= 0.12927471
# step) 90 Accuracy(IOU)= 0.12945548
# step) 91 Accuracy(IOU)= 0.13001686
# step) 92 Accuracy(IOU)= 0.12902875
# step) 93 Accuracy(IOU)= 0.13130088
# step) 94 Accuracy(IOU)= 0.13241605
# step) 95 Accuracy(IOU)= 0.13200925
# step) 96 Accuracy(IOU)= 0.13227342
# step) 97 Accuracy(IOU)= 0.13293852
# step) 98 Accuracy(IOU)= 0.13479467
# step) 99 Accuracy(IOU)= 0.13568515
# step) 100 Accuracy(IOU)= 0.13649367
# step) 101 Accuracy(IOU)= 0.1354685
# step) 102 Accuracy(IOU)= 0.13774753
# step) 103 Accuracy(IOU)= 0.14177658
# step) 104 Accuracy(IOU)= 0.14166203
# step) 105 Accuracy(IOU)= 0.14231731
# step) 106 Accuracy(IOU)= 0.14289849
# step) 107 Accuracy(IOU)= 0.1446627
# step) 108 Accuracy(IOU)= 0.14417265
# step) 109 Accuracy(IOU)= 0.14516567
# step) 110 Accuracy(IOU)= 0.14454654
# step) 111 Accuracy(IOU)= 0.1456329
# step) 112 Accuracy(IOU)= 0.14522022
# step) 113 Accuracy(IOU)= 0.14470853
# step) 114 Accuracy(IOU)= 0.14351487
# step) 115 Accuracy(IOU)= 0.1424729
# step) 116 Accuracy(IOU)= 0.14429206
# step) 117 Accuracy(IOU)= 0.14433539
# step) 118 Accuracy(IOU)= 0.1465667
# step) 119 Accuracy(IOU)= 0.14621088
# step) 120 Accuracy(IOU)= 0.14765401
# step) 121 Accuracy(IOU)= 0.14716268
# step) 122 Accuracy(IOU)= 0.14904796
# step) 123 Accuracy(IOU)= 0.1493217
# step) 124 Accuracy(IOU)= 0.15070282
# step) 125 Accuracy(IOU)= 0.15252315
# step) 126 Accuracy(IOU)= 0.15238565
# step) 127 Accuracy(IOU)= 0.15187739
# step) 128 Accuracy(IOU)= 0.15199718
# step) 129 Accuracy(IOU)= 0.15510306
# step) 130 Accuracy(IOU)= 0.15481313
# step) 131 Accuracy(IOU)= 0.15763511
# step) 132 Accuracy(IOU)= 0.15811907
# step) 133 Accuracy(IOU)= 0.15844741
# step) 134 Accuracy(IOU)= 0.15812124
# step) 135 Accuracy(IOU)= 0.15969548
# step) 136 Accuracy(IOU)= 0.15957789
# step) 137 Accuracy(IOU)= 0.16020823
# step) 138 Accuracy(IOU)= 0.1606813
# step) 139 Accuracy(IOU)= 0.16031727
# step) 140 Accuracy(IOU)= 0.16153252
# step) 141 Accuracy(IOU)= 0.16188164
# step) 142 Accuracy(IOU)= 0.16133972
# step) 143 Accuracy(IOU)= 0.1637003
# step) 144 Accuracy(IOU)= 0.16357745
# step) 145 Accuracy(IOU)= 0.16289961
# step) 146 Accuracy(IOU)= 0.1668252
# step) 147 Accuracy(IOU)= 0.1668063
# step) 148 Accuracy(IOU)= 0.16776863
# step) 149 Accuracy(IOU)= 0.16722557
# step) 150 Accuracy(IOU)= 0.1672128
# step) 151 Accuracy(IOU)= 0.16757472
# step) 152 Accuracy(IOU)= 0.1676196
# step) 153 Accuracy(IOU)= 0.1695125
# step) 154 Accuracy(IOU)= 0.1706558
# step) 155 Accuracy(IOU)= 0.17141846
# step) 156 Accuracy(IOU)= 0.17110007
# step) 157 Accuracy(IOU)= 0.17119329
# step) 159 Accuracy(IOU)= 0.17206575
# step) 160 Accuracy(IOU)= 0.17299399
# step) 161 Accuracy(IOU)= 0.17353597
# step) 162 Accuracy(IOU)= 0.1722037
# step) 163 Accuracy(IOU)= 0.17438285
# step) 164 Accuracy(IOU)= 0.17473358
# step) 165 Accuracy(IOU)= 0.1752226
# step) 166 Accuracy(IOU)= 0.17863385
# step) 167 Accuracy(IOU)= 0.17847711
# step) 168 Accuracy(IOU)= 0.1802118
# step) 169 Accuracy(IOU)= 0.18009195
# step) 170 Accuracy(IOU)= 0.1801955
# step) 171 Accuracy(IOU)= 0.1819101
# step) 172 Accuracy(IOU)= 0.18464825
# step) 173 Accuracy(IOU)= 0.18422341
# step) 174 Accuracy(IOU)= 0.18445064
# step) 175 Accuracy(IOU)= 0.1842181
# step) 176 Accuracy(IOU)= 0.18732926
# step) 177 Accuracy(IOU)= 0.18693347
# step) 178 Accuracy(IOU)= 0.18853596
# step) 179 Accuracy(IOU)= 0.18912444
# step) 180 Accuracy(IOU)= 0.19040088
# step) 181 Accuracy(IOU)= 0.19185208
# step) 182 Accuracy(IOU)= 0.19145602
# step) 183 Accuracy(IOU)= 0.19138435
# step) 184 Accuracy(IOU)= 0.19070363
# step) 185 Accuracy(IOU)= 0.19180827
# step) 186 Accuracy(IOU)= 0.19274117
# step) 187 Accuracy(IOU)= 0.19360656
# step) 188 Accuracy(IOU)= 0.19395165
# step) 189 Accuracy(IOU)= 0.19405168
# step) 190 Accuracy(IOU)= 0.19522683
# step) 191 Accuracy(IOU)= 0.1947071
# step) 192 Accuracy(IOU)= 0.19407916
# step) 193 Accuracy(IOU)= 0.1955678
# step) 194 Accuracy(IOU)= 0.19606507
# step) 195 Accuracy(IOU)= 0.19891071
# step) 196 Accuracy(IOU)= 0.19949917
# step) 197 Accuracy(IOU)= 0.19874874
# step) 198 Accuracy(IOU)= 0.19820435
# step) 199 Accuracy(IOU)= 0.19990316
# step) 200 Accuracy(IOU)= 0.20033759
# step) 201 Accuracy(IOU)= 0.20123416
# step) 202 Accuracy(IOU)= 0.20144908
# step) 203 Accuracy(IOU)= 0.20257433
# step) 204 Accuracy(IOU)= 0.2024158
# step) 205 Accuracy(IOU)= 0.20312726
# step) 206 Accuracy(IOU)= 0.20452936
# step) 207 Accuracy(IOU)= 0.20402436
# step) 208 Accuracy(IOU)= 0.20346451
# step) 209 Accuracy(IOU)= 0.20471258
# step) 210 Accuracy(IOU)= 0.20594054
# step) 211 Accuracy(IOU)= 0.20641933
# step) 212 Accuracy(IOU)= 0.20832975
# step) 213 Accuracy(IOU)= 0.20797662
# step) 214 Accuracy(IOU)= 0.20971337
# step) 215 Accuracy(IOU)= 0.20884675
# step) 216 Accuracy(IOU)= 0.21082114
# step) 217 Accuracy(IOU)= 0.21124904
# step) 218 Accuracy(IOU)= 0.21218869
# step) 219 Accuracy(IOU)= 0.21107103
# step) 220 Accuracy(IOU)= 0.21386725
# step) 221 Accuracy(IOU)= 0.21353085
# step) 222 Accuracy(IOU)= 0.21329938
# step) 223 Accuracy(IOU)= 0.21433708
# step) 224 Accuracy(IOU)= 0.21717063
# step) 225 Accuracy(IOU)= 0.21568128
# step) 226 Accuracy(IOU)= 0.21710601
# step) 227 Accuracy(IOU)= 0.21850844
# step) 228 Accuracy(IOU)= 0.22140765
# step) 229 Accuracy(IOU)= 0.22123128
# step) 230 Accuracy(IOU)= 0.22079004
# step) 231 Accuracy(IOU)= 0.22070672
# step) 232 Accuracy(IOU)= 0.22160427
# step) 233 Accuracy(IOU)= 0.22786543
# step) 234 Accuracy(IOU)= 0.22961304
# step) 235 Accuracy(IOU)= 0.23705952
# step) 236 Accuracy(IOU)= 0.23752643
# step) 237 Accuracy(IOU)= 0.23848769
# step) 238 Accuracy(IOU)= 0.23727787
# step) 239 Accuracy(IOU)= 0.23728311
# step) 240 Accuracy(IOU)= 0.23493235
# step) 241 Accuracy(IOU)= 0.23586
# step) 242 Accuracy(IOU)= 0.23494397
# step) 243 Accuracy(IOU)= 0.23612085
# step) 244 Accuracy(IOU)= 0.23648335
# step) 245 Accuracy(IOU)= 0.23651178
# step) 246 Accuracy(IOU)= 0.23653035
# step) 247 Accuracy(IOU)= 0.23645458
# step) 248 Accuracy(IOU)= 0.23819995
# step) 249 Accuracy(IOU)= 0.2384239
# step) 250 Accuracy(IOU)= 0.23755194
# step) 251 Accuracy(IOU)= 0.23660049
# step) 252 Accuracy(IOU)= 0.23814236
# step) 253 Accuracy(IOU)= 0.23819219
# step) 254 Accuracy(IOU)= 0.24240956
# step) 255 Accuracy(IOU)= 0.24186474
# step) 256 Accuracy(IOU)= 0.24267091
# step) 257 Accuracy(IOU)= 0.24263366
# step) 258 Accuracy(IOU)= 0.242035
# step) 259 Accuracy(IOU)= 0.24280103
# step) 260 Accuracy(IOU)= 0.24136162
# step) 261 Accuracy(IOU)= 0.24270324
# step) 262 Accuracy(IOU)= 0.24124224
# step) 263 Accuracy(IOU)= 0.24182603
# step) 264 Accuracy(IOU)= 0.23991829
# step) 265 Accuracy(IOU)= 0.24014644
# step) 266 Accuracy(IOU)= 0.24046923
# step) 267 Accuracy(IOU)= 0.24080195
# step) 268 Accuracy(IOU)= 0.24172059
# step) 269 Accuracy(IOU)= 0.24086721
# step) 270 Accuracy(IOU)= 0.23966129
# step) 271 Accuracy(IOU)= 0.2417439
# step) 272 Accuracy(IOU)= 0.24430722
# step) 273 Accuracy(IOU)= 0.24260773
# step) 274 Accuracy(IOU)= 0.24243747
# step) 275 Accuracy(IOU)= 0.24381925
# step) 276 Accuracy(IOU)= 0.24496207
# step) 277 Accuracy(IOU)= 0.24525054
# step) 278 Accuracy(IOU)= 0.24468632
# step) 279 Accuracy(IOU)= 0.24471818
# step) 280 Accuracy(IOU)= 0.2437802
# step) 281 Accuracy(IOU)= 0.24543726
# step) 282 Accuracy(IOU)= 0.24788207
# step) 283 Accuracy(IOU)= 0.24951099
# step) 284 Accuracy(IOU)= 0.2504786
# step) 285 Accuracy(IOU)= 0.25022575
# step) 286 Accuracy(IOU)= 0.24853458
# step) 287 Accuracy(IOU)= 0.24648681
# step) 288 Accuracy(IOU)= 0.245142
# step) 289 Accuracy(IOU)= 0.24700858
# step) 290 Accuracy(IOU)= 0.24765955
# step) 291 Accuracy(IOU)= 0.24911086
# step) 292 Accuracy(IOU)= 0.25064135
# step) 293 Accuracy(IOU)= 0.25083667
# step) 294 Accuracy(IOU)= 0.25245717
# step) 295 Accuracy(IOU)= 0.25268668
# step) 296 Accuracy(IOU)= 0.25131834
# step) 297 Accuracy(IOU)= 0.2505214
# step) 298 Accuracy(IOU)= 0.25074902
# step) 299 Accuracy(IOU)= 0.2511308
# step) 300 Accuracy(IOU)= 0.2516201
# step) 301 Accuracy(IOU)= 0.25378537
# step) 302 Accuracy(IOU)= 0.25358918
# step) 303 Accuracy(IOU)= 0.25161716
# step) 304 Accuracy(IOU)= 0.253102
# step) 305 Accuracy(IOU)= 0.25384885
# step) 306 Accuracy(IOU)= 0.25512123
# step) 307 Accuracy(IOU)= 0.2542488
# step) 308 Accuracy(IOU)= 0.25274786
# step) 309 Accuracy(IOU)= 0.25262773
# step) 310 Accuracy(IOU)= 0.25176096
# step) 311 Accuracy(IOU)= 0.25417176
# step) 312 Accuracy(IOU)= 0.25304437
# step) 313 Accuracy(IOU)= 0.25463194
# step) 314 Accuracy(IOU)= 0.25445107
# step) 315 Accuracy(IOU)= 0.25412282
# step) 316 Accuracy(IOU)= 0.25378463
# step) 317 Accuracy(IOU)= 0.2556697
# step) 318 Accuracy(IOU)= 0.25381264
# step) 319 Accuracy(IOU)= 0.25301498
# step) 320 Accuracy(IOU)= 0.25464272
# step) 321 Accuracy(IOU)= 0.2556736
# step) 322 Accuracy(IOU)= 0.25504264
# step) 323 Accuracy(IOU)= 0.2550202
# step) 324 Accuracy(IOU)= 0.2544528
# step) 325 Accuracy(IOU)= 0.25213274
# step) 326 Accuracy(IOU)= 0.25207248
# step) 327 Accuracy(IOU)= 0.2525779
# step) 328 Accuracy(IOU)= 0.2518696
# step) 329 Accuracy(IOU)= 0.25092134
# step) 330 Accuracy(IOU)= 0.25166595
# step) 331 Accuracy(IOU)= 0.2520519
# step) 332 Accuracy(IOU)= 0.25485757
# step) 333 Accuracy(IOU)= 0.25264323
# step) 334 Accuracy(IOU)= 0.25380656
# step) 335 Accuracy(IOU)= 0.25440434
# step) 336 Accuracy(IOU)= 0.25327483
# step) 337 Accuracy(IOU)= 0.25158048
# step) 338 Accuracy(IOU)= 0.2520735
# step) 339 Accuracy(IOU)= 0.2530899
# step) 340 Accuracy(IOU)= 0.25245452
# step) 341 Accuracy(IOU)= 0.25195304
# step) 342 Accuracy(IOU)= 0.25247803
# step) 343 Accuracy(IOU)= 0.25349173
# step) 344 Accuracy(IOU)= 0.25404486
# step) 345 Accuracy(IOU)= 0.25529882
# step) 346 Accuracy(IOU)= 0.25559676
# step) 348 Accuracy(IOU)= 0.25580895
# step) 349 Accuracy(IOU)= 0.2541871
# step) 350 Accuracy(IOU)= 0.25414693
# step) 351 Accuracy(IOU)= 0.25359434
# step) 352 Accuracy(IOU)= 0.25286025
# step) 353 Accuracy(IOU)= 0.25604102
# step) 354 Accuracy(IOU)= 0.25715628
# step) 355 Accuracy(IOU)= 0.2579343
# step) 356 Accuracy(IOU)= 0.25943652
# step) 357 Accuracy(IOU)= 0.26002958
# step) 358 Accuracy(IOU)= 0.2581894
# step) 359 Accuracy(IOU)= 0.25983557
# step) 360 Accuracy(IOU)= 0.25788492
# step) 361 Accuracy(IOU)= 0.2581728
# step) 362 Accuracy(IOU)= 0.25727525
# step) 363 Accuracy(IOU)= 0.25795346
# step) 364 Accuracy(IOU)= 0.25982082
# step) 365 Accuracy(IOU)= 0.2600838
# step) 366 Accuracy(IOU)= 0.25887024
# step) 367 Accuracy(IOU)= 0.2610088
# step) 368 Accuracy(IOU)= 0.260415
# step) 369 Accuracy(IOU)= 0.26059648
# step) 370 Accuracy(IOU)= 0.26187038
# step) 371 Accuracy(IOU)= 0.2623377
# step) 372 Accuracy(IOU)= 0.26086813
# step) 373 Accuracy(IOU)= 0.26249683
# step) 374 Accuracy(IOU)= 0.26225716
# step) 375 Accuracy(IOU)= 0.2639431
# step) 376 Accuracy(IOU)= 0.26297125
# step) 377 Accuracy(IOU)= 0.26332036
# step) 378 Accuracy(IOU)= 0.26281497
# step) 379 Accuracy(IOU)= 0.26165178
# step) 380 Accuracy(IOU)= 0.26253936
# step) 381 Accuracy(IOU)= 0.26407
# step) 382 Accuracy(IOU)= 0.26493034
# step) 383 Accuracy(IOU)= 0.26574844
# step) 384 Accuracy(IOU)= 0.26477736
# step) 385 Accuracy(IOU)= 0.26443034
# step) 386 Accuracy(IOU)= 0.26555339
# step) 387 Accuracy(IOU)= 0.26452002
# step) 388 Accuracy(IOU)= 0.26416856
# step) 389 Accuracy(IOU)= 0.26949853
# step) 390 Accuracy(IOU)= 0.26948687
# step) 391 Accuracy(IOU)= 0.26895854
# step) 392 Accuracy(IOU)= 0.27049103
# step) 393 Accuracy(IOU)= 0.2718443
# step) 394 Accuracy(IOU)= 0.27136815
# step) 395 Accuracy(IOU)= 0.27075195
# step) 396 Accuracy(IOU)= 0.27026442
# step) 397 Accuracy(IOU)= 0.2711698
# step) 398 Accuracy(IOU)= 0.27091575
# step) 399 Accuracy(IOU)= 0.2710077
# step) 400 Accuracy(IOU)= 0.26983503
# step) 401 Accuracy(IOU)= 0.2698907
# step) 402 Accuracy(IOU)= 0.27071583
# step) 403 Accuracy(IOU)= 0.2689908
# step) 404 Accuracy(IOU)= 0.26993883
# step) 405 Accuracy(IOU)= 0.27019936
# step) 406 Accuracy(IOU)= 0.26932293
# step) 407 Accuracy(IOU)= 0.26812658
# step) 408 Accuracy(IOU)= 0.26857215
# step) 409 Accuracy(IOU)= 0.26853684
# step) 410 Accuracy(IOU)= 0.2696551
# step) 411 Accuracy(IOU)= 0.26884162
# step) 412 Accuracy(IOU)= 0.2704981
# step) 413 Accuracy(IOU)= 0.2691815
# step) 414 Accuracy(IOU)= 0.2709913
# step) 415 Accuracy(IOU)= 0.2720914
# step) 416 Accuracy(IOU)= 0.27181736
# step) 417 Accuracy(IOU)= 0.27174377
# step) 418 Accuracy(IOU)= 0.26958507
# step) 419 Accuracy(IOU)= 0.27061257
# step) 420 Accuracy(IOU)= 0.26884252
# step) 421 Accuracy(IOU)= 0.2686016
# step) 422 Accuracy(IOU)= 0.26851615
# step) 423 Accuracy(IOU)= 0.2671451
# step) 424 Accuracy(IOU)= 0.2675675
# step) 425 Accuracy(IOU)= 0.26778424
# step) 426 Accuracy(IOU)= 0.26853445
# step) 427 Accuracy(IOU)= 0.26647994
# step) 428 Accuracy(IOU)= 0.26686618
# step) 429 Accuracy(IOU)= 0.26854515
# step) 430 Accuracy(IOU)= 0.27019823
# step) 431 Accuracy(IOU)= 0.26955247
# step) 432 Accuracy(IOU)= 0.26717544
# step) 433 Accuracy(IOU)= 0.2707102
# step) 434 Accuracy(IOU)= 0.27065998
# step) 435 Accuracy(IOU)= 0.26999158
# step) 436 Accuracy(IOU)= 0.27012673
# step) 437 Accuracy(IOU)= 0.2694716
# step) 438 Accuracy(IOU)= 0.2687821
# step) 439 Accuracy(IOU)= 0.26922047
# step) 440 Accuracy(IOU)= 0.27078742
# step) 441 Accuracy(IOU)= 0.27217433
# step) 442 Accuracy(IOU)= 0.26976454
# step) 443 Accuracy(IOU)= 0.27045652
# step) 444 Accuracy(IOU)= 0.27314115
# step) 445 Accuracy(IOU)= 0.27473882
# step) 446 Accuracy(IOU)= 0.27387503
# step) 447 Accuracy(IOU)= 0.27344114
# step) 448 Accuracy(IOU)= 0.2714035
# step) 449 Accuracy(IOU)= 0.27094832
# step) 450 Accuracy(IOU)= 0.2687941
# step) 451 Accuracy(IOU)= 0.26781288
# step) 452 Accuracy(IOU)= 0.26568308
# step) 453 Accuracy(IOU)= 0.2668573
# step) 454 Accuracy(IOU)= 0.2661597
# step) 455 Accuracy(IOU)= 0.26759082
# step) 456 Accuracy(IOU)= 0.2668829
# step) 457 Accuracy(IOU)= 0.26433223
# step) 458 Accuracy(IOU)= 0.26472774
# step) 459 Accuracy(IOU)= 0.2647671
# step) 460 Accuracy(IOU)= 0.26410425
# step) 461 Accuracy(IOU)= 0.26362023
# step) 462 Accuracy(IOU)= 0.2649116
# step) 463 Accuracy(IOU)= 0.26550338
# step) 464 Accuracy(IOU)= 0.265355
# step) 465 Accuracy(IOU)= 0.26603752
# step) 466 Accuracy(IOU)= 0.26585662
# step) 467 Accuracy(IOU)= 0.2661732
# step) 468 Accuracy(IOU)= 0.26730186
# step) 469 Accuracy(IOU)= 0.26744962
# step) 470 Accuracy(IOU)= 0.2674707
# step) 471 Accuracy(IOU)= 0.26717815
# step) 472 Accuracy(IOU)= 0.267321
# step) 473 Accuracy(IOU)= 0.26691
# step) 474 Accuracy(IOU)= 0.26816958
# step) 475 Accuracy(IOU)= 0.27180958
# step) 476 Accuracy(IOU)= 0.27182382
# step) 477 Accuracy(IOU)= 0.27122408
# step) 478 Accuracy(IOU)= 0.26963925
# step) 479 Accuracy(IOU)= 0.26766345
# step) 480 Accuracy(IOU)= 0.2666456
# step) 481 Accuracy(IOU)= 0.26644275
# step) 482 Accuracy(IOU)= 0.26575354
# step) 483 Accuracy(IOU)= 0.26749703
# step) 484 Accuracy(IOU)= 0.26620883
# step) 485 Accuracy(IOU)= 0.2655278
# step) 486 Accuracy(IOU)= 0.2669596
# step) 487 Accuracy(IOU)= 0.26544273
# step) 488 Accuracy(IOU)= 0.26803067
# step) 489 Accuracy(IOU)= 0.26775223
# step) 490 Accuracy(IOU)= 0.2700462
# step) 491 Accuracy(IOU)= 0.2702424
# step) 492 Accuracy(IOU)= 0.27241609
# step) 493 Accuracy(IOU)= 0.2730773
# step) 494 Accuracy(IOU)= 0.27526006
# step) 495 Accuracy(IOU)= 0.27467203
# step) 496 Accuracy(IOU)= 0.27482435
# step) 497 Accuracy(IOU)= 0.27320102
# step) 498 Accuracy(IOU)= 0.27503788
# step) 499 Accuracy(IOU)= 0.27518678
# step) 500 Accuracy(IOU)= 0.27769533
# step) 501 Accuracy(IOU)= 0.27747476
# step) 502 Accuracy(IOU)= 0.2783348
# step) 503 Accuracy(IOU)= 0.27762285
# step) 504 Accuracy(IOU)= 0.27551737
# step) 505 Accuracy(IOU)= 0.27472758
# step) 506 Accuracy(IOU)= 0.27432582
# step) 507 Accuracy(IOU)= 0.272047
# step) 508 Accuracy(IOU)= 0.27299085
# step) 509 Accuracy(IOU)= 0.27272058
# step) 510 Accuracy(IOU)= 0.2716379
# step) 511 Accuracy(IOU)= 0.27165142
# step) 512 Accuracy(IOU)= 0.2714962
# step) 513 Accuracy(IOU)= 0.26932362
# step) 514 Accuracy(IOU)= 0.2691378
# step) 515 Accuracy(IOU)= 0.26976338
# step) 516 Accuracy(IOU)= 0.27138838
# step) 517 Accuracy(IOU)= 0.2699574
# step) 518 Accuracy(IOU)= 0.2681337
# step) 519 Accuracy(IOU)= 0.26624876
# step) 520 Accuracy(IOU)= 0.26604968
# step) 521 Accuracy(IOU)= 0.26484284
# step) 522 Accuracy(IOU)= 0.26378682
# step) 523 Accuracy(IOU)= 0.26498318
# step) 524 Accuracy(IOU)= 0.26518127
# step) 525 Accuracy(IOU)= 0.2641038
# step) 526 Accuracy(IOU)= 0.2629617
# step) 527 Accuracy(IOU)= 0.26398337
# step) 528 Accuracy(IOU)= 0.26620692
# step) 529 Accuracy(IOU)= 0.26501122
# step) 530 Accuracy(IOU)= 0.26285392
# step) 531 Accuracy(IOU)= 0.26192647
# step) 532 Accuracy(IOU)= 0.26142958
# step) 533 Accuracy(IOU)= 0.25983214
# step) 534 Accuracy(IOU)= 0.25920486
# step) 535 Accuracy(IOU)= 0.26052016
# step) 536 Accuracy(IOU)= 0.25996983
# step) 537 Accuracy(IOU)= 0.26051572
# step) 538 Accuracy(IOU)= 0.26137865
# step) 539 Accuracy(IOU)= 0.2630387
# step) 540 Accuracy(IOU)= 0.2621248
# step) 541 Accuracy(IOU)= 0.2620253
# step) 542 Accuracy(IOU)= 0.26258042
# step) 543 Accuracy(IOU)= 0.26130104
# step) 545 Accuracy(IOU)= 0.26165766
# step) 546 Accuracy(IOU)= 0.26012868
# step) 547 Accuracy(IOU)= 0.26122385
# step) 548 Accuracy(IOU)= 0.26296565
# step) 549 Accuracy(IOU)= 0.26488584
# step) 550 Accuracy(IOU)= 0.26443037
# step) 551 Accuracy(IOU)= 0.2640161
# step) 552 Accuracy(IOU)= 0.26427478
# step) 553 Accuracy(IOU)= 0.26531383
# step) 554 Accuracy(IOU)= 0.26863897
# step) 555 Accuracy(IOU)= 0.27003014
# step) 556 Accuracy(IOU)= 0.26911235
# step) 557 Accuracy(IOU)= 0.2718195
# step) 558 Accuracy(IOU)= 0.2717331
# step) 559 Accuracy(IOU)= 0.27216807
# step) 560 Accuracy(IOU)= 0.27316383
# step) 561 Accuracy(IOU)= 0.2722782
# step) 562 Accuracy(IOU)= 0.27217886
# step) 563 Accuracy(IOU)= 0.27316326
# step) 564 Accuracy(IOU)= 0.27200285
# step) 565 Accuracy(IOU)= 0.27021486
# step) 566 Accuracy(IOU)= 0.27024
# step) 567 Accuracy(IOU)= 0.27277088
# step) 568 Accuracy(IOU)= 0.27273798
# step) 569 Accuracy(IOU)= 0.27245477
# step) 570 Accuracy(IOU)= 0.27221027
# step) 571 Accuracy(IOU)= 0.27253842
# step) 572 Accuracy(IOU)= 0.27269924
# step) 573 Accuracy(IOU)= 0.27276263
# step) 574 Accuracy(IOU)= 0.27367353
# step) 575 Accuracy(IOU)= 0.2745543
# step) 576 Accuracy(IOU)= 0.27431893
# step) 577 Accuracy(IOU)= 0.27293435
# step) 578 Accuracy(IOU)= 0.2733252
# step) 579 Accuracy(IOU)= 0.2732372
# step) 580 Accuracy(IOU)= 0.27160764
# step) 581 Accuracy(IOU)= 0.27014518
# step) 582 Accuracy(IOU)= 0.27239665
# step) 583 Accuracy(IOU)= 0.27138332
# step) 584 Accuracy(IOU)= 0.27391988
# step) 585 Accuracy(IOU)= 0.2734203
# step) 586 Accuracy(IOU)= 0.27230197
# step) 587 Accuracy(IOU)= 0.27234644
# step) 588 Accuracy(IOU)= 0.272729
# step) 589 Accuracy(IOU)= 0.2722743
# step) 590 Accuracy(IOU)= 0.2732854
# step) 591 Accuracy(IOU)= 0.2719662
# step) 592 Accuracy(IOU)= 0.27435383
# step) 593 Accuracy(IOU)= 0.2756156
# step) 594 Accuracy(IOU)= 0.27541968
# step) 595 Accuracy(IOU)= 0.27655402
# step) 596 Accuracy(IOU)= 0.27620435
# step) 597 Accuracy(IOU)= 0.2758744
# step) 598 Accuracy(IOU)= 0.27792987
# step) 599 Accuracy(IOU)= 0.27675053
# step) 600 Accuracy(IOU)= 0.27452073
# step) 601 Accuracy(IOU)= 0.2741552
# step) 602 Accuracy(IOU)= 0.273619
# step) 603 Accuracy(IOU)= 0.2731171
# step) 604 Accuracy(IOU)= 0.27255207
# step) 605 Accuracy(IOU)= 0.27356145
# step) 606 Accuracy(IOU)= 0.27459654
# step) 607 Accuracy(IOU)= 0.27352127
# step) 608 Accuracy(IOU)= 0.272746
# step) 609 Accuracy(IOU)= 0.27562717
# step) 610 Accuracy(IOU)= 0.2745752
# step) 611 Accuracy(IOU)= 0.27514943
# step) 612 Accuracy(IOU)= 0.27448204
# step) 613 Accuracy(IOU)= 0.27585077
# step) 614 Accuracy(IOU)= 0.27357116
# step) 615 Accuracy(IOU)= 0.27346212
# step) 616 Accuracy(IOU)= 0.2756183
# step) 617 Accuracy(IOU)= 0.27443424
# step) 618 Accuracy(IOU)= 0.27438164
# step) 619 Accuracy(IOU)= 0.2730121
# step) 620 Accuracy(IOU)= 0.2741138
# step) 621 Accuracy(IOU)= 0.2736979
# step) 622 Accuracy(IOU)= 0.27411357
# step) 623 Accuracy(IOU)= 0.27396902
# step) 624 Accuracy(IOU)= 0.27346876
# step) 625 Accuracy(IOU)= 0.27142248
# step) 626 Accuracy(IOU)= 0.27015454
# step) 627 Accuracy(IOU)= 0.27018204
# step) 628 Accuracy(IOU)= 0.26817274
# step) 629 Accuracy(IOU)= 0.2713721
# step) 630 Accuracy(IOU)= 0.27194878
# step) 631 Accuracy(IOU)= 0.26996198
# step) 632 Accuracy(IOU)= 0.27063605
# step) 633 Accuracy(IOU)= 0.27184153
# step) 634 Accuracy(IOU)= 0.27284008
# step) 635 Accuracy(IOU)= 0.27134255
# step) 636 Accuracy(IOU)= 0.26985407
# step) 637 Accuracy(IOU)= 0.27108133
# step) 638 Accuracy(IOU)= 0.27193335
# step) 639 Accuracy(IOU)= 0.27145812
# step) 640 Accuracy(IOU)= 0.2712724
# step) 641 Accuracy(IOU)= 0.27282172
# step) 642 Accuracy(IOU)= 0.27225256
# step) 643 Accuracy(IOU)= 0.27032337
# step) 644 Accuracy(IOU)= 0.27191684
# step) 645 Accuracy(IOU)= 0.26994786
# step) 646 Accuracy(IOU)= 0.27054086
# step) 647 Accuracy(IOU)= 0.27002078
# step) 648 Accuracy(IOU)= 0.26904738
# step) 649 Accuracy(IOU)= 0.26869288
# step) 650 Accuracy(IOU)= 0.26770326
# step) 651 Accuracy(IOU)= 0.2710228
# step) 652 Accuracy(IOU)= 0.27089435
# step) 653 Accuracy(IOU)= 0.2702788
# step) 654 Accuracy(IOU)= 0.27033523
# step) 655 Accuracy(IOU)= 0.2714035
# step) 656 Accuracy(IOU)= 0.27210283
# step) 657 Accuracy(IOU)= 0.2721931
# step) 658 Accuracy(IOU)= 0.27325878
# step) 659 Accuracy(IOU)= 0.27497184
# step) 660 Accuracy(IOU)= 0.27491334
# step) 661 Accuracy(IOU)= 0.27596128
# step) 662 Accuracy(IOU)= 0.27409863
# step) 663 Accuracy(IOU)= 0.27549443
# step) 664 Accuracy(IOU)= 0.27698374
# step) 665 Accuracy(IOU)= 0.27711242
# step) 666 Accuracy(IOU)= 0.27648255
# step) 667 Accuracy(IOU)= 0.27595785
# step) 668 Accuracy(IOU)= 0.27574804
# step) 669 Accuracy(IOU)= 0.27543196
# step) 670 Accuracy(IOU)= 0.276609
# step) 671 Accuracy(IOU)= 0.27866757
# step) 672 Accuracy(IOU)= 0.27755097
# step) 673 Accuracy(IOU)= 0.27846146
# step) 674 Accuracy(IOU)= 0.27965793
# step) 675 Accuracy(IOU)= 0.27941433
# step) 676 Accuracy(IOU)= 0.2786038
# step) 677 Accuracy(IOU)= 0.2773589
# step) 678 Accuracy(IOU)= 0.27930507
# step) 679 Accuracy(IOU)= 0.27854493
# step) 680 Accuracy(IOU)= 0.2772009
# step) 681 Accuracy(IOU)= 0.27872837
# step) 682 Accuracy(IOU)= 0.2787675
# step) 683 Accuracy(IOU)= 0.27931124
# step) 684 Accuracy(IOU)= 0.27871794
# step) 685 Accuracy(IOU)= 0.2778603
# step) 686 Accuracy(IOU)= 0.27571878
# step) 687 Accuracy(IOU)= 0.27510682
# step) 688 Accuracy(IOU)= 0.27608395
# step) 689 Accuracy(IOU)= 0.277231
# step) 690 Accuracy(IOU)= 0.27633956
# step) 691 Accuracy(IOU)= 0.27499747
# step) 692 Accuracy(IOU)= 0.27540472
# step) 693 Accuracy(IOU)= 0.27618143
# step) 694 Accuracy(IOU)= 0.27650675
# step) 695 Accuracy(IOU)= 0.28136134
# step) 696 Accuracy(IOU)= 0.2809545
# step) 697 Accuracy(IOU)= 0.28078002
# step) 698 Accuracy(IOU)= 0.2818857
# step) 699 Accuracy(IOU)= 0.28146386
# step) 700 Accuracy(IOU)= 0.28108114
# step) 701 Accuracy(IOU)= 0.27842733
# step) 702 Accuracy(IOU)= 0.27710932
# step) 703 Accuracy(IOU)= 0.277111
# step) 704 Accuracy(IOU)= 0.27783817
# step) 705 Accuracy(IOU)= 0.27693272
# step) 706 Accuracy(IOU)= 0.2767139
# step) 707 Accuracy(IOU)= 0.27846003
# step) 708 Accuracy(IOU)= 0.28002462
# step) 709 Accuracy(IOU)= 0.27779528
# step) 710 Accuracy(IOU)= 0.27681008
# step) 711 Accuracy(IOU)= 0.2770248
# step) 712 Accuracy(IOU)= 0.27653596
# step) 713 Accuracy(IOU)= 0.27643296
# step) 714 Accuracy(IOU)= 0.2757532
# step) 715 Accuracy(IOU)= 0.27580446
# step) 716 Accuracy(IOU)= 0.27634624
# step) 717 Accuracy(IOU)= 0.27735728
# step) 718 Accuracy(IOU)= 0.2772655
# step) 719 Accuracy(IOU)= 0.27531636
# step) 720 Accuracy(IOU)= 0.27612305
# step) 721 Accuracy(IOU)= 0.27724007
# step) 722 Accuracy(IOU)= 0.27745378
# step) 723 Accuracy(IOU)= 0.27698672
# step) 724 Accuracy(IOU)= 0.27919993
# step) 725 Accuracy(IOU)= 0.28195837
# step) 726 Accuracy(IOU)= 0.2819978
# step) 727 Accuracy(IOU)= 0.28098622
# step) 728 Accuracy(IOU)= 0.28167197
# step) 729 Accuracy(IOU)= 0.28373507
# step) 730 Accuracy(IOU)= 0.28294265
# step) 731 Accuracy(IOU)= 0.28151554
# step) 732 Accuracy(IOU)= 0.28002098
# step) 733 Accuracy(IOU)= 0.27965865
# step) 734 Accuracy(IOU)= 0.28117335
# step) 735 Accuracy(IOU)= 0.28364417
# step) 736 Accuracy(IOU)= 0.2862085
# step) 737 Accuracy(IOU)= 0.287755
# step) 738 Accuracy(IOU)= 0.28674707
# step) 739 Accuracy(IOU)= 0.28588402
# step) 740 Accuracy(IOU)= 0.2851873
# step) 741 Accuracy(IOU)= 0.28502283
# step) 742 Accuracy(IOU)= 0.28602284
# step) 743 Accuracy(IOU)= 0.28595698
# step) 744 Accuracy(IOU)= 0.2848038
# step) 745 Accuracy(IOU)= 0.285759
# step) 746 Accuracy(IOU)= 0.286818
# step) 747 Accuracy(IOU)= 0.28545594
# step) 748 Accuracy(IOU)= 0.28416786
# step) 749 Accuracy(IOU)= 0.28378484
# step) 750 Accuracy(IOU)= 0.28318796
# step) 751 Accuracy(IOU)= 0.28411567
# step) 752 Accuracy(IOU)= 0.2836349
# step) 753 Accuracy(IOU)= 0.28475067
# step) 754 Accuracy(IOU)= 0.2853351
# step) 755 Accuracy(IOU)= 0.28428644
# step) 756 Accuracy(IOU)= 0.28456053
# step) 757 Accuracy(IOU)= 0.28453812
# step) 758 Accuracy(IOU)= 0.28572935
# step) 759 Accuracy(IOU)= 0.28678173
# step) 760 Accuracy(IOU)= 0.28780302
# step) 761 Accuracy(IOU)= 0.28779894
# step) 762 Accuracy(IOU)= 0.28645504
# step) 763 Accuracy(IOU)= 0.2854624
# step) 764 Accuracy(IOU)= 0.28404835
# step) 765 Accuracy(IOU)= 0.28477567
# step) 766 Accuracy(IOU)= 0.28513134
# step) 767 Accuracy(IOU)= 0.28398967
# step) 768 Accuracy(IOU)= 0.283462
# step) 769 Accuracy(IOU)= 0.28592882
# step) 770 Accuracy(IOU)= 0.28681314
# step) 771 Accuracy(IOU)= 0.28796688
# step) 772 Accuracy(IOU)= 0.28566596
# step) 773 Accuracy(IOU)= 0.284079
# step) 774 Accuracy(IOU)= 0.28292513
# step) 775 Accuracy(IOU)= 0.2843662
# step) 776 Accuracy(IOU)= 0.28424656
# step) 777 Accuracy(IOU)= 0.28396067
# step) 778 Accuracy(IOU)= 0.28322878
# step) 779 Accuracy(IOU)= 0.28311783
# step) 780 Accuracy(IOU)= 0.2880069
# step) 781 Accuracy(IOU)= 0.28840086
# step) 782 Accuracy(IOU)= 0.29134834
# step) 783 Accuracy(IOU)= 0.29135486
# step) 784 Accuracy(IOU)= 0.29033783
# step) 785 Accuracy(IOU)= 0.28953004
# step) 786 Accuracy(IOU)= 0.28928953
# step) 787 Accuracy(IOU)= 0.28862
# step) 788 Accuracy(IOU)= 0.28770486
# step) 789 Accuracy(IOU)= 0.28776896
# step) 790 Accuracy(IOU)= 0.2889676
# step) 791 Accuracy(IOU)= 0.2885322
# step) 792 Accuracy(IOU)= 0.2893819
# step) 793 Accuracy(IOU)= 0.28830433
# step) 794 Accuracy(IOU)= 0.2874883
# step) 795 Accuracy(IOU)= 0.28793618
# step) 796 Accuracy(IOU)= 0.28813243
# step) 797 Accuracy(IOU)= 0.28935075
# step) 798 Accuracy(IOU)= 0.29176265
# step) 799 Accuracy(IOU)= 0.29076076
# step) 800 Accuracy(IOU)= 0.29306227
# step) 801 Accuracy(IOU)= 0.29163474
# step) 802 Accuracy(IOU)= 0.29286402
# step) 803 Accuracy(IOU)= 0.29147732
# step) 804 Accuracy(IOU)= 0.29029953
# step) 805 Accuracy(IOU)= 0.29322758
# step) 806 Accuracy(IOU)= 0.29175344
# step) 807 Accuracy(IOU)= 0.28995073
# step) 808 Accuracy(IOU)= 0.29168248
# step) 809 Accuracy(IOU)= 0.2904305
# step) 810 Accuracy(IOU)= 0.2893895
# step) 811 Accuracy(IOU)= 0.29094824
# step) 812 Accuracy(IOU)= 0.29056644
# step) 813 Accuracy(IOU)= 0.29125783
# step) 814 Accuracy(IOU)= 0.29105654
# step) 815 Accuracy(IOU)= 0.29118407
# step) 816 Accuracy(IOU)= 0.29101318
# step) 817 Accuracy(IOU)= 0.29045403
# step) 818 Accuracy(IOU)= 0.290719
# step) 819 Accuracy(IOU)= 0.29142907
# step) 820 Accuracy(IOU)= 0.29184645
# step) 821 Accuracy(IOU)= 0.29199073
# step) 822 Accuracy(IOU)= 0.2920701
# step) 823 Accuracy(IOU)= 0.29305276
# step) 824 Accuracy(IOU)= 0.2932539
# step) 825 Accuracy(IOU)= 0.29402882
# step) 826 Accuracy(IOU)= 0.2999542
# step) 827 Accuracy(IOU)= 0.29981697
# step) 828 Accuracy(IOU)= 0.29876763
# step) 829 Accuracy(IOU)= 0.29798427
# step) 830 Accuracy(IOU)= 0.29818624
# step) 831 Accuracy(IOU)= 0.2959659
# step) 832 Accuracy(IOU)= 0.29548106
# step) 833 Accuracy(IOU)= 0.29629713
# step) 834 Accuracy(IOU)= 0.29531008
# step) 835 Accuracy(IOU)= 0.29530784
# step) 836 Accuracy(IOU)= 0.29397193
# step) 837 Accuracy(IOU)= 0.2933605
# step) 838 Accuracy(IOU)= 0.29939508
# step) 839 Accuracy(IOU)= 0.29648706
# step) 840 Accuracy(IOU)= 0.2953385
# step) 841 Accuracy(IOU)= 0.29482734
# step) 842 Accuracy(IOU)= 0.2948728
# step) 843 Accuracy(IOU)= 0.29295546
# step) 844 Accuracy(IOU)= 0.2912951
# step) 845 Accuracy(IOU)= 0.2918172
# step) 846 Accuracy(IOU)= 0.29272544
# step) 847 Accuracy(IOU)= 0.2915936
# step) 848 Accuracy(IOU)= 0.2904336
# step) 849 Accuracy(IOU)= 0.2900923
# step) 850 Accuracy(IOU)= 0.28975675
# step) 851 Accuracy(IOU)= 0.29012308
# step) 852 Accuracy(IOU)= 0.28930962
# step) 853 Accuracy(IOU)= 0.2902516
# step) 854 Accuracy(IOU)= 0.29194146
# step) 855 Accuracy(IOU)= 0.289535
# step) 856 Accuracy(IOU)= 0.28848985
# step) 857 Accuracy(IOU)= 0.28967863
# step) 858 Accuracy(IOU)= 0.29043624
# step) 859 Accuracy(IOU)= 0.2903798
# step) 860 Accuracy(IOU)= 0.29101616
# step) 861 Accuracy(IOU)= 0.29179063
# step) 862 Accuracy(IOU)= 0.29033822
# step) 863 Accuracy(IOU)= 0.29215962
# step) 864 Accuracy(IOU)= 0.2928223
# step) 865 Accuracy(IOU)= 0.29404607
# step) 866 Accuracy(IOU)= 0.29570007
# step) 867 Accuracy(IOU)= 0.2955039
# step) 868 Accuracy(IOU)= 0.2937146
# step) 869 Accuracy(IOU)= 0.29403102
# step) 870 Accuracy(IOU)= 0.293334
# step) 871 Accuracy(IOU)= 0.29421303
# step) 872 Accuracy(IOU)= 0.29461986
# step) 873 Accuracy(IOU)= 0.29536587
# step) 874 Accuracy(IOU)= 0.29395562
# step) 875 Accuracy(IOU)= 0.30089778
# step) 876 Accuracy(IOU)= 0.3001877
# step) 877 Accuracy(IOU)= 0.29765555
# step) 878 Accuracy(IOU)= 0.29818732
# step) 879 Accuracy(IOU)= 0.2969715
# step) 880 Accuracy(IOU)= 0.29887816
# step) 881 Accuracy(IOU)= 0.2971549
# step) 882 Accuracy(IOU)= 0.29543003
# step) 883 Accuracy(IOU)= 0.29610085
# step) 884 Accuracy(IOU)= 0.294017
# step) 885 Accuracy(IOU)= 0.2948802
# step) 886 Accuracy(IOU)= 0.29521456
# step) 887 Accuracy(IOU)= 0.29699144
# step) 888 Accuracy(IOU)= 0.2975282
# step) 890 Accuracy(IOU)= 0.30064785
# step) 891 Accuracy(IOU)= 0.30107546
# step) 892 Accuracy(IOU)= 0.300478
# step) 893 Accuracy(IOU)= 0.30264378
# step) 894 Accuracy(IOU)= 0.30121017
# step) 895 Accuracy(IOU)= 0.30097193
# step) 896 Accuracy(IOU)= 0.30055767
# step) 897 Accuracy(IOU)= 0.2981152
# step) 898 Accuracy(IOU)= 0.29827356
# step) 899 Accuracy(IOU)= 0.3004384
# step) 900 Accuracy(IOU)= 0.29889256
# step) 901 Accuracy(IOU)= 0.29885536
# step) 902 Accuracy(IOU)= 0.29922855
# step) 903 Accuracy(IOU)= 0.29813534
# step) 904 Accuracy(IOU)= 0.29762703
# step) 905 Accuracy(IOU)= 0.2962134
# step) 906 Accuracy(IOU)= 0.29681408
# step) 907 Accuracy(IOU)= 0.295914
# step) 908 Accuracy(IOU)= 0.29526067
# step) 909 Accuracy(IOU)= 0.29571962
# step) 910 Accuracy(IOU)= 0.29792187
# step) 911 Accuracy(IOU)= 0.2988116
# step) 912 Accuracy(IOU)= 0.3002995
# step) 913 Accuracy(IOU)= 0.30085412
# step) 914 Accuracy(IOU)= 0.29842144
# step) 915 Accuracy(IOU)= 0.29895842
# step) 916 Accuracy(IOU)= 0.29948896
# step) 917 Accuracy(IOU)= 0.29971707
# step) 918 Accuracy(IOU)= 0.30051297
# step) 919 Accuracy(IOU)= 0.29939863
# step) 920 Accuracy(IOU)= 0.3007884
# step) 921 Accuracy(IOU)= 0.30261207
# step) 922 Accuracy(IOU)= 0.3036841
# step) 923 Accuracy(IOU)= 0.3028032
# step) 924 Accuracy(IOU)= 0.30097863
# step) 925 Accuracy(IOU)= 0.30101484
# step) 926 Accuracy(IOU)= 0.30164495
# step) 927 Accuracy(IOU)= 0.2987769
# step) 928 Accuracy(IOU)= 0.29874772
# step) 929 Accuracy(IOU)= 0.29730073
# step) 930 Accuracy(IOU)= 0.29575542
# step) 931 Accuracy(IOU)= 0.2963956
# step) 932 Accuracy(IOU)= 0.29586133
# step) 933 Accuracy(IOU)= 0.29818
# step) 934 Accuracy(IOU)= 0.29656526
# step) 935 Accuracy(IOU)= 0.29535842
# step) 936 Accuracy(IOU)= 0.29520965
# step) 937 Accuracy(IOU)= 0.2955293
# step) 938 Accuracy(IOU)= 0.29554042
# step) 939 Accuracy(IOU)= 0.29443765
# step) 940 Accuracy(IOU)= 0.29400557
# step) 941 Accuracy(IOU)= 0.29465312
# step) 942 Accuracy(IOU)= 0.29469523
# step) 943 Accuracy(IOU)= 0.2938562
# step) 944 Accuracy(IOU)= 0.2911944
# step) 945 Accuracy(IOU)= 0.29073948
# step) 946 Accuracy(IOU)= 0.28977585
# step) 947 Accuracy(IOU)= 0.29196924
# step) 948 Accuracy(IOU)= 0.29111925
# step) 949 Accuracy(IOU)= 0.28966004
# step) 950 Accuracy(IOU)= 0.2884741
# step) 951 Accuracy(IOU)= 0.29162595
# step) 952 Accuracy(IOU)= 0.29296747
# step) 953 Accuracy(IOU)= 0.29490307
# step) 954 Accuracy(IOU)= 0.29614958
# step) 955 Accuracy(IOU)= 0.30252534
# step) 956 Accuracy(IOU)= 0.30020347
# step) 957 Accuracy(IOU)= 0.2979984
# step) 958 Accuracy(IOU)= 0.29868907
# step) 959 Accuracy(IOU)= 0.2983961
# step) 960 Accuracy(IOU)= 0.29766986
# step) 961 Accuracy(IOU)= 0.29708916
# step) 962 Accuracy(IOU)= 0.29682976
# step) 963 Accuracy(IOU)= 0.29944763
# step) 964 Accuracy(IOU)= 0.29780364
# step) 965 Accuracy(IOU)= 0.299402
# step) 966 Accuracy(IOU)= 0.29776514
# step) 967 Accuracy(IOU)= 0.29782066
# step) 968 Accuracy(IOU)= 0.29916695
# step) 969 Accuracy(IOU)= 0.29945403
# step) 970 Accuracy(IOU)= 0.2999679
# step) 971 Accuracy(IOU)= 0.30080476
# step) 972 Accuracy(IOU)= 0.30344433
# step) 973 Accuracy(IOU)= 0.3033939
# step) 974 Accuracy(IOU)= 0.30510876
# step) 975 Accuracy(IOU)= 0.30535495
# step) 976 Accuracy(IOU)= 0.3043188
# step) 977 Accuracy(IOU)= 0.3025264
# step) 978 Accuracy(IOU)= 0.30226287
# step) 979 Accuracy(IOU)= 0.30284768
# step) 980 Accuracy(IOU)= 0.30401993
# step) 981 Accuracy(IOU)= 0.30388623
# step) 982 Accuracy(IOU)= 0.30481192
# step) 983 Accuracy(IOU)= 0.30366945
# step) 984 Accuracy(IOU)= 0.30152473
# step) 985 Accuracy(IOU)= 0.30123985
# step) 986 Accuracy(IOU)= 0.3014899
# step) 987 Accuracy(IOU)= 0.3005021
# step) 988 Accuracy(IOU)= 0.29809192
# step) 989 Accuracy(IOU)= 0.29750973
# step) 990 Accuracy(IOU)= 0.29675728
# step) 991 Accuracy(IOU)= 0.2958199
# step) 992 Accuracy(IOU)= 0.29388857
# step) 993 Accuracy(IOU)= 0.29198366
# step) 994 Accuracy(IOU)= 0.2921574
# step) 995 Accuracy(IOU)= 0.29325765
# step) 996 Accuracy(IOU)= 0.29355502
# step) 997 Accuracy(IOU)= 0.29299527
# step) 998 Accuracy(IOU)= 0.2931742
# step) 999 Accuracy(IOU)= 0.2938944
# save model
# step) 1000 Accuracy(IOU)= 0.2934555
# step) 1001 Accuracy(IOU)= 0.29460263
# step) 1002 Accuracy(IOU)= 0.29643387
# step) 1003 Accuracy(IOU)= 0.29744935
# step) 1004 Accuracy(IOU)= 0.29596272
# step) 1005 Accuracy(IOU)= 0.2954175
# step) 1006 Accuracy(IOU)= 0.29421338
# step) 1007 Accuracy(IOU)= 0.29470682
# step) 1008 Accuracy(IOU)= 0.30138722
# step) 1009 Accuracy(IOU)= 0.30209178
# step) 1010 Accuracy(IOU)= 0.30061814
# step) 1011 Accuracy(IOU)= 0.30075553
# step) 1012 Accuracy(IOU)= 0.30250978
# step) 1013 Accuracy(IOU)= 0.30063686
# step) 1014 Accuracy(IOU)= 0.29974186
# step) 1015 Accuracy(IOU)= 0.29902053
# step) 1016 Accuracy(IOU)= 0.29892215
# step) 1017 Accuracy(IOU)= 0.29755574
# step) 1018 Accuracy(IOU)= 0.297966
# step) 1019 Accuracy(IOU)= 0.29753578
# step) 1020 Accuracy(IOU)= 0.2962821
# step) 1021 Accuracy(IOU)= 0.2936535
# step) 1022 Accuracy(IOU)= 0.29425725
# step) 1023 Accuracy(IOU)= 0.29799852
# step) 1024 Accuracy(IOU)= 0.2992258
# step) 1025 Accuracy(IOU)= 0.30022064
# step) 1026 Accuracy(IOU)= 0.29853803
# step) 1027 Accuracy(IOU)= 0.29616427
# step) 1028 Accuracy(IOU)= 0.2964654
# step) 1029 Accuracy(IOU)= 0.298101
# step) 1030 Accuracy(IOU)= 0.2966437
# step) 1031 Accuracy(IOU)= 0.29502556
# step) 1032 Accuracy(IOU)= 0.29545957
# step) 1033 Accuracy(IOU)= 0.29745343
# step) 1034 Accuracy(IOU)= 0.2973309
# step) 1035 Accuracy(IOU)= 0.29701293
# step) 1036 Accuracy(IOU)= 0.2951738
# step) 1037 Accuracy(IOU)= 0.29670843
# step) 1038 Accuracy(IOU)= 0.2961747
# step) 1039 Accuracy(IOU)= 0.29527974
# step) 1040 Accuracy(IOU)= 0.2963857
# step) 1041 Accuracy(IOU)= 0.29506618
# step) 1042 Accuracy(IOU)= 0.296996
# step) 1043 Accuracy(IOU)= 0.29668617
# step) 1044 Accuracy(IOU)= 0.29721567
# step) 1045 Accuracy(IOU)= 0.29655123
# step) 1046 Accuracy(IOU)= 0.29618636
# step) 1047 Accuracy(IOU)= 0.2981521
# step) 1048 Accuracy(IOU)= 0.2967238
# step) 1049 Accuracy(IOU)= 0.29966614
# step) 1050 Accuracy(IOU)= 0.298887
# step) 1051 Accuracy(IOU)= 0.29952577
# step) 1052 Accuracy(IOU)= 0.2980826
# step) 1053 Accuracy(IOU)= 0.2996102
# step) 1054 Accuracy(IOU)= 0.29859212
# step) 1055 Accuracy(IOU)= 0.296024
# step) 1056 Accuracy(IOU)= 0.29805127
# step) 1057 Accuracy(IOU)= 0.29863214
# step) 1058 Accuracy(IOU)= 0.30552214
# step) 1059 Accuracy(IOU)= 0.30464965
# step) 1060 Accuracy(IOU)= 0.30286846
# step) 1061 Accuracy(IOU)= 0.30366772
# step) 1062 Accuracy(IOU)= 0.30458295
# step) 1063 Accuracy(IOU)= 0.30359897
# step) 1064 Accuracy(IOU)= 0.30452514
# step) 1065 Accuracy(IOU)= 0.30326685
# step) 1066 Accuracy(IOU)= 0.3045939
# step) 1067 Accuracy(IOU)= 0.30524915
# step) 1068 Accuracy(IOU)= 0.3045065
# step) 1069 Accuracy(IOU)= 0.30370829
# step) 1070 Accuracy(IOU)= 0.30290052
# step) 1071 Accuracy(IOU)= 0.30257615
# step) 1072 Accuracy(IOU)= 0.3033939
# step) 1073 Accuracy(IOU)= 0.3030956
# step) 1074 Accuracy(IOU)= 0.30243507
# step) 1075 Accuracy(IOU)= 0.30111563
# step) 1076 Accuracy(IOU)= 0.29906183
# step) 1077 Accuracy(IOU)= 0.29851624
# step) 1078 Accuracy(IOU)= 0.30097753
# step) 1079 Accuracy(IOU)= 0.29985058
# step) 1080 Accuracy(IOU)= 0.29943216
# step) 1081 Accuracy(IOU)= 0.299949
# step) 1082 Accuracy(IOU)= 0.29840016
# step) 1083 Accuracy(IOU)= 0.29880726
# step) 1084 Accuracy(IOU)= 0.29935956
# step) 1085 Accuracy(IOU)= 0.29786512
# step) 1086 Accuracy(IOU)= 0.29799256
# step) 1087 Accuracy(IOU)= 0.2977938
# step) 1088 Accuracy(IOU)= 0.29797837
# step) 1089 Accuracy(IOU)= 0.29929236
# step) 1090 Accuracy(IOU)= 0.30155876
# step) 1091 Accuracy(IOU)= 0.30174512
# step) 1092 Accuracy(IOU)= 0.30267385
# step) 1093 Accuracy(IOU)= 0.30326903
# step) 1094 Accuracy(IOU)= 0.30267295
# step) 1095 Accuracy(IOU)= 0.3013891
# step) 1096 Accuracy(IOU)= 0.3013965
# step) 1097 Accuracy(IOU)= 0.302545
# step) 1098 Accuracy(IOU)= 0.30315694
# step) 1099 Accuracy(IOU)= 0.30222967
# step) 1100 Accuracy(IOU)= 0.30295566
# step) 1101 Accuracy(IOU)= 0.3006797
# step) 1102 Accuracy(IOU)= 0.30629864
# step) 1103 Accuracy(IOU)= 0.30715394
# step) 1104 Accuracy(IOU)= 0.30627987
# step) 1105 Accuracy(IOU)= 0.3063697
# step) 1106 Accuracy(IOU)= 0.30694717
# step) 1107 Accuracy(IOU)= 0.30824172
# step) 1108 Accuracy(IOU)= 0.3080198
# step) 1109 Accuracy(IOU)= 0.3085122
# step) 1110 Accuracy(IOU)= 0.30693462
# step) 1111 Accuracy(IOU)= 0.3081157
# step) 1112 Accuracy(IOU)= 0.31292346
# step) 1113 Accuracy(IOU)= 0.31211188
# step) 1114 Accuracy(IOU)= 0.31204066
# step) 1115 Accuracy(IOU)= 0.31090814
# step) 1116 Accuracy(IOU)= 0.31092513
# step) 1117 Accuracy(IOU)= 0.30824015
# step) 1118 Accuracy(IOU)= 0.30789834
# step) 1119 Accuracy(IOU)= 0.30803496
# step) 1120 Accuracy(IOU)= 0.3071477
# step) 1121 Accuracy(IOU)= 0.3058656
# step) 1122 Accuracy(IOU)= 0.30837283
# step) 1123 Accuracy(IOU)= 0.30802384
# step) 1124 Accuracy(IOU)= 0.3068397
# step) 1125 Accuracy(IOU)= 0.30737686
# step) 1126 Accuracy(IOU)= 0.30768216
# step) 1127 Accuracy(IOU)= 0.30948934
# step) 1128 Accuracy(IOU)= 0.3098368
# step) 1129 Accuracy(IOU)= 0.31031644
# step) 1130 Accuracy(IOU)= 0.30894437
# step) 1131 Accuracy(IOU)= 0.30872527
# step) 1132 Accuracy(IOU)= 0.30748895
# step) 1133 Accuracy(IOU)= 0.3078215
# step) 1134 Accuracy(IOU)= 0.3078185
# step) 1135 Accuracy(IOU)= 0.31024805
# step) 1136 Accuracy(IOU)= 0.31015524
# step) 1137 Accuracy(IOU)= 0.30947688
# step) 1138 Accuracy(IOU)= 0.30891356
# step) 1139 Accuracy(IOU)= 0.30984566
# step) 1140 Accuracy(IOU)= 0.3095291
# step) 1141 Accuracy(IOU)= 0.30816498
# step) 1142 Accuracy(IOU)= 0.30855983
# step) 1143 Accuracy(IOU)= 0.3102629
# step) 1144 Accuracy(IOU)= 0.30918115
# step) 1145 Accuracy(IOU)= 0.30791304
# step) 1146 Accuracy(IOU)= 0.3060234
# step) 1147 Accuracy(IOU)= 0.305254
# step) 1148 Accuracy(IOU)= 0.30358088
# step) 1149 Accuracy(IOU)= 0.30163994
# step) 1150 Accuracy(IOU)= 0.30101985
# step) 1151 Accuracy(IOU)= 0.30183497
# step) 1152 Accuracy(IOU)= 0.302585
# step) 1153 Accuracy(IOU)= 0.3024701
# step) 1154 Accuracy(IOU)= 0.30154747
# step) 1155 Accuracy(IOU)= 0.30356926
# step) 1156 Accuracy(IOU)= 0.30244178
# step) 1157 Accuracy(IOU)= 0.30326787
# step) 1158 Accuracy(IOU)= 0.30330795
# step) 1159 Accuracy(IOU)= 0.3021471
# step) 1160 Accuracy(IOU)= 0.30336675
# step) 1161 Accuracy(IOU)= 0.30199176
# step) 1162 Accuracy(IOU)= 0.3028322
# step) 1163 Accuracy(IOU)= 0.30268005
# step) 1164 Accuracy(IOU)= 0.30344614
# step) 1165 Accuracy(IOU)= 0.30235845
# step) 1166 Accuracy(IOU)= 0.30236638
# step) 1167 Accuracy(IOU)= 0.30392486
# step) 1168 Accuracy(IOU)= 0.3043433
# step) 1169 Accuracy(IOU)= 0.30533427
# step) 1170 Accuracy(IOU)= 0.30606163
# step) 1171 Accuracy(IOU)= 0.30633152
# step) 1172 Accuracy(IOU)= 0.3052996
# step) 1173 Accuracy(IOU)= 0.30363676
# step) 1174 Accuracy(IOU)= 0.30285677
# step) 1175 Accuracy(IOU)= 0.30118838
# step) 1176 Accuracy(IOU)= 0.30118102
# step) 1177 Accuracy(IOU)= 0.29838312
# step) 1178 Accuracy(IOU)= 0.29840896
# step) 1179 Accuracy(IOU)= 0.29797176
# step) 1180 Accuracy(IOU)= 0.29797268
# step) 1181 Accuracy(IOU)= 0.2957362
# step) 1182 Accuracy(IOU)= 0.30268633
# step) 1183 Accuracy(IOU)= 0.30229637
# step) 1184 Accuracy(IOU)= 0.30439508
# step) 1185 Accuracy(IOU)= 0.30750492
# step) 1186 Accuracy(IOU)= 0.30588418
# step) 1187 Accuracy(IOU)= 0.30614266
# step) 1188 Accuracy(IOU)= 0.3066907
# step) 1189 Accuracy(IOU)= 0.3115104
# step) 1190 Accuracy(IOU)= 0.31051907
# step) 1191 Accuracy(IOU)= 0.3089894
# step) 1192 Accuracy(IOU)= 0.30768725
# step) 1193 Accuracy(IOU)= 0.30709794
# step) 1194 Accuracy(IOU)= 0.30606437
# step) 1195 Accuracy(IOU)= 0.30313307
# step) 1196 Accuracy(IOU)= 0.3006726
# step) 1197 Accuracy(IOU)= 0.30047566
# step) 1198 Accuracy(IOU)= 0.29867303
# step) 1199 Accuracy(IOU)= 0.2988017
# step) 1200 Accuracy(IOU)= 0.29945594
# step) 1201 Accuracy(IOU)= 0.2997098
# step) 1202 Accuracy(IOU)= 0.2991056
# step) 1203 Accuracy(IOU)= 0.30025548
# step) 1204 Accuracy(IOU)= 0.3014025
# step) 1205 Accuracy(IOU)= 0.30028635
# step) 1206 Accuracy(IOU)= 0.29970282
# step) 1207 Accuracy(IOU)= 0.30089092
# step) 1208 Accuracy(IOU)= 0.29990178
# step) 1209 Accuracy(IOU)= 0.30118278
# step) 1210 Accuracy(IOU)= 0.3001665
# step) 1211 Accuracy(IOU)= 0.29892308
# step) 1212 Accuracy(IOU)= 0.29900095
# step) 1213 Accuracy(IOU)= 0.296339
# step) 1214 Accuracy(IOU)= 0.2984532
# step) 1215 Accuracy(IOU)= 0.2977463
# step) 1216 Accuracy(IOU)= 0.2962881
# step) 1217 Accuracy(IOU)= 0.29423216
# step) 1218 Accuracy(IOU)= 0.29390237
# step) 1219 Accuracy(IOU)= 0.2928527
# step) 1220 Accuracy(IOU)= 0.29198676
# step) 1221 Accuracy(IOU)= 0.292345
# step) 1222 Accuracy(IOU)= 0.2924096
# step) 1223 Accuracy(IOU)= 0.2936661
# step) 1224 Accuracy(IOU)= 0.29400218
# step) 1225 Accuracy(IOU)= 0.29536217
# step) 1226 Accuracy(IOU)= 0.29857504
# step) 1227 Accuracy(IOU)= 0.29921633
# step) 1228 Accuracy(IOU)= 0.29944372
# step) 1229 Accuracy(IOU)= 0.297633
# step) 1230 Accuracy(IOU)= 0.2972838
# step) 1231 Accuracy(IOU)= 0.30080682
# step) 1232 Accuracy(IOU)= 0.30146563
# step) 1233 Accuracy(IOU)= 0.30315095
# step) 1234 Accuracy(IOU)= 0.3028519
# step) 1235 Accuracy(IOU)= 0.30199793
# step) 1236 Accuracy(IOU)= 0.30271024
# step) 1237 Accuracy(IOU)= 0.30270338
# step) 1238 Accuracy(IOU)= 0.30257687
# step) 1239 Accuracy(IOU)= 0.30129924
# step) 1240 Accuracy(IOU)= 0.30166036
# step) 1241 Accuracy(IOU)= 0.30546534
# step) 1242 Accuracy(IOU)= 0.30578348
# step) 1243 Accuracy(IOU)= 0.30495408
# step) 1244 Accuracy(IOU)= 0.30578196
# step) 1245 Accuracy(IOU)= 0.30277553
# step) 1246 Accuracy(IOU)= 0.30123657
# step) 1247 Accuracy(IOU)= 0.3033177
# step) 1248 Accuracy(IOU)= 0.3026767
# step) 1249 Accuracy(IOU)= 0.30135304
# step) 1250 Accuracy(IOU)= 0.30104098
# step) 1251 Accuracy(IOU)= 0.3017986
# step) 1252 Accuracy(IOU)= 0.29886916
# step) 1253 Accuracy(IOU)= 0.29593223
# step) 1254 Accuracy(IOU)= 0.29528284
# step) 1255 Accuracy(IOU)= 0.29591873
# step) 1256 Accuracy(IOU)= 0.29564887
# step) 1257 Accuracy(IOU)= 0.29780737
# step) 1258 Accuracy(IOU)= 0.29999438
# step) 1259 Accuracy(IOU)= 0.29821494
# step) 1260 Accuracy(IOU)= 0.29754212
# step) 1261 Accuracy(IOU)= 0.2987766
# step) 1262 Accuracy(IOU)= 0.30211625
# step) 1263 Accuracy(IOU)= 0.30210218
# step) 1264 Accuracy(IOU)= 0.29988793
# step) 1265 Accuracy(IOU)= 0.30210674
# step) 1266 Accuracy(IOU)= 0.3011915
# step) 1267 Accuracy(IOU)= 0.30343574
# step) 1268 Accuracy(IOU)= 0.30202252
# step) 1269 Accuracy(IOU)= 0.30380827
# step) 1270 Accuracy(IOU)= 0.30616522
# step) 1271 Accuracy(IOU)= 0.30623597
# step) 1272 Accuracy(IOU)= 0.30363825
# step) 1273 Accuracy(IOU)= 0.30430338
# step) 1274 Accuracy(IOU)= 0.30149785
# step) 1275 Accuracy(IOU)= 0.299932
# step) 1276 Accuracy(IOU)= 0.29991356
# step) 1277 Accuracy(IOU)= 0.29813513
# step) 1278 Accuracy(IOU)= 0.29741377
# step) 1279 Accuracy(IOU)= 0.29502577
# step) 1280 Accuracy(IOU)= 0.2955507
# step) 1281 Accuracy(IOU)= 0.29398128
# step) 1282 Accuracy(IOU)= 0.29183176
# step) 1283 Accuracy(IOU)= 0.28970814
# step) 1284 Accuracy(IOU)= 0.28869128
# step) 1285 Accuracy(IOU)= 0.28826103
# step) 1286 Accuracy(IOU)= 0.2907794
# step) 1287 Accuracy(IOU)= 0.2897814
# step) 1288 Accuracy(IOU)= 0.28916848
# step) 1289 Accuracy(IOU)= 0.28743052
# step) 1290 Accuracy(IOU)= 0.2881854
# step) 1291 Accuracy(IOU)= 0.2870353
# step) 1292 Accuracy(IOU)= 0.28445342
# step) 1293 Accuracy(IOU)= 0.28743634
# step) 1294 Accuracy(IOU)= 0.2862805
# step) 1295 Accuracy(IOU)= 0.28810856
# step) 1296 Accuracy(IOU)= 0.2877628
# step) 1297 Accuracy(IOU)= 0.28871047
# step) 1298 Accuracy(IOU)= 0.2891933
# step) 1299 Accuracy(IOU)= 0.28950927
# step) 1300 Accuracy(IOU)= 0.29276922
# step) 1301 Accuracy(IOU)= 0.29306406
# step) 1302 Accuracy(IOU)= 0.29315037
# step) 1303 Accuracy(IOU)= 0.29362223
# step) 1304 Accuracy(IOU)= 0.2939881
# step) 1305 Accuracy(IOU)= 0.2922534
# step) 1306 Accuracy(IOU)= 0.2911972
# step) 1307 Accuracy(IOU)= 0.29108465
# step) 1308 Accuracy(IOU)= 0.29118395
# step) 1309 Accuracy(IOU)= 0.2906841
# step) 1310 Accuracy(IOU)= 0.2894763
# step) 1311 Accuracy(IOU)= 0.290147
# step) 1312 Accuracy(IOU)= 0.29257357
# step) 1313 Accuracy(IOU)= 0.29200104
# step) 1314 Accuracy(IOU)= 0.29217908
# step) 1315 Accuracy(IOU)= 0.29395172
# step) 1316 Accuracy(IOU)= 0.29226694
# step) 1317 Accuracy(IOU)= 0.2926565
# step) 1318 Accuracy(IOU)= 0.29075962
# step) 1319 Accuracy(IOU)= 0.29038596
# step) 1320 Accuracy(IOU)= 0.29031533
# step) 1321 Accuracy(IOU)= 0.29092565
# step) 1322 Accuracy(IOU)= 0.29114476
# step) 1323 Accuracy(IOU)= 0.28972188
# step) 1324 Accuracy(IOU)= 0.28858674
# step) 1325 Accuracy(IOU)= 0.28792027
# step) 1326 Accuracy(IOU)= 0.28762195
# ...
# step) 68631 Accuracy(IOU)= 0.41572958
# step) 68632 Accuracy(IOU)= 0.41667563
# step) 68633 Accuracy(IOU)= 0.41545013
# step) 68634 Accuracy(IOU)= 0.4211875
# step) 68635 Accuracy(IOU)= 0.42037967
# step) 68636 Accuracy(IOU)= 0.42126235
# step) 68637 Accuracy(IOU)= 0.42296234
# step) 68638 Accuracy(IOU)= 0.42546704
# step) 68639 Accuracy(IOU)= 0.4262783
# step) 68640 Accuracy(IOU)= 0.42702982
# step) 68641 Accuracy(IOU)= 0.42501122
# step) 68642 Accuracy(IOU)= 0.42632374
# step) 68643 Accuracy(IOU)= 0.4248595
# step) 68644 Accuracy(IOU)= 0.42351964
# step) 68645 Accuracy(IOU)= 0.42482135
# step) 68646 Accuracy(IOU)= 0.423986
# step) 68647 Accuracy(IOU)= 0.42260647
# step) 68648 Accuracy(IOU)= 0.4226892
# step) 68649 Accuracy(IOU)= 0.424103
# step) 68650 Accuracy(IOU)= 0.42311686
# step) 68651 Accuracy(IOU)= 0.42294136
# step) 68652 Accuracy(IOU)= 0.42202482
# step) 68653 Accuracy(IOU)= 0.4222132
# step) 68654 Accuracy(IOU)= 0.42121214
# step) 68655 Accuracy(IOU)= 0.42371938
# step) 68656 Accuracy(IOU)= 0.42324612
# step) 68657 Accuracy(IOU)= 0.42263657
# step) 68658 Accuracy(IOU)= 0.42444518
# step) 68659 Accuracy(IOU)= 0.42458513
# step) 68660 Accuracy(IOU)= 0.42318824
# step) 68661 Accuracy(IOU)= 0.42159465
# step) 68662 Accuracy(IOU)= 0.42008895
# step) 68663 Accuracy(IOU)= 0.4185049
# step) 68664 Accuracy(IOU)= 0.4200209
# step) 68665 Accuracy(IOU)= 0.41957632
# step) 68666 Accuracy(IOU)= 0.4208055
# step) 68667 Accuracy(IOU)= 0.42073378
# step) 68668 Accuracy(IOU)= 0.42143577
# step) 68669 Accuracy(IOU)= 0.42278504
# step) 68670 Accuracy(IOU)= 0.4285426
# step) 68671 Accuracy(IOU)= 0.42756408
# step) 68672 Accuracy(IOU)= 0.42683536
# step) 68673 Accuracy(IOU)= 0.43111625
# step) 68674 Accuracy(IOU)= 0.43201938
# step) 68675 Accuracy(IOU)= 0.43389374
# step) 68676 Accuracy(IOU)= 0.43467307
# step) 68677 Accuracy(IOU)= 0.4347611
# step) 68678 Accuracy(IOU)= 0.43613937
# step) 68679 Accuracy(IOU)= 0.4349563
# step) 68680 Accuracy(IOU)= 0.43575293
# step) 68681 Accuracy(IOU)= 0.4360957
# step) 68682 Accuracy(IOU)= 0.43676183
# step) 68683 Accuracy(IOU)= 0.44014734
# step) 68684 Accuracy(IOU)= 0.44461313
# step) 68685 Accuracy(IOU)= 0.44409445
# step) 68686 Accuracy(IOU)= 0.44342402
# step) 68687 Accuracy(IOU)= 0.44474506
# step) 68688 Accuracy(IOU)= 0.44672927
# step) 68689 Accuracy(IOU)= 0.446037
# step) 68690 Accuracy(IOU)= 0.44768435
# step) 68691 Accuracy(IOU)= 0.44878867
# step) 68692 Accuracy(IOU)= 0.44844434
# step) 68693 Accuracy(IOU)= 0.44692943
# step) 68694 Accuracy(IOU)= 0.4466211
# step) 68695 Accuracy(IOU)= 0.44631255
# step) 68696 Accuracy(IOU)= 0.44616595
# step) 68697 Accuracy(IOU)= 0.4421737
# step) 68698 Accuracy(IOU)= 0.43922165
# step) 68699 Accuracy(IOU)= 0.4372007
# step) 68700 Accuracy(IOU)= 0.43678308
# step) 68701 Accuracy(IOU)= 0.43573624
# step) 68702 Accuracy(IOU)= 0.43550143
# step) 68703 Accuracy(IOU)= 0.4358159
# step) 68704 Accuracy(IOU)= 0.43486527
# step) 68705 Accuracy(IOU)= 0.4321984
# step) 68706 Accuracy(IOU)= 0.4305298
# step) 68707 Accuracy(IOU)= 0.43025726
# step) 68708 Accuracy(IOU)= 0.4304495
# step) 68709 Accuracy(IOU)= 0.42931572
# step) 68710 Accuracy(IOU)= 0.42823872
# step) 68711 Accuracy(IOU)= 0.42696857
# step) 68712 Accuracy(IOU)= 0.4265799
# step) 68713 Accuracy(IOU)= 0.42540586
# step) 68714 Accuracy(IOU)= 0.4253521
# step) 68715 Accuracy(IOU)= 0.4247666
# step) 68716 Accuracy(IOU)= 0.42608172
# step) 68717 Accuracy(IOU)= 0.42347413
# step) 68718 Accuracy(IOU)= 0.42455363
# step) 68719 Accuracy(IOU)= 0.42449042
# step) 68720 Accuracy(IOU)= 0.42528298
# step) 68721 Accuracy(IOU)= 0.42512876
# step) 68722 Accuracy(IOU)= 0.42430016
# step) 68723 Accuracy(IOU)= 0.4237793
# step) 68724 Accuracy(IOU)= 0.4234163
# step) 68725 Accuracy(IOU)= 0.42500982
# step) 68726 Accuracy(IOU)= 0.42487773
# step) 68727 Accuracy(IOU)= 0.42469224
# step) 68728 Accuracy(IOU)= 0.42476255
# step) 68729 Accuracy(IOU)= 0.42419046
# step) 68730 Accuracy(IOU)= 0.42433107
# step) 68731 Accuracy(IOU)= 0.4241678
# step) 68732 Accuracy(IOU)= 0.42547315
# step) 68733 Accuracy(IOU)= 0.4238129
# step) 68734 Accuracy(IOU)= 0.42429706
# step) 68735 Accuracy(IOU)= 0.4216336
# step) 68736 Accuracy(IOU)= 0.4218182
# step) 68737 Accuracy(IOU)= 0.4241713
# step) 68738 Accuracy(IOU)= 0.42395183
# step) 68739 Accuracy(IOU)= 0.42278686
# step) 68740 Accuracy(IOU)= 0.4208511
# step) 68741 Accuracy(IOU)= 0.42320445
# step) 68742 Accuracy(IOU)= 0.4224454
# step) 68743 Accuracy(IOU)= 0.42387694
# step) 68744 Accuracy(IOU)= 0.42315927
# step) 68745 Accuracy(IOU)= 0.42506748
# step) 68746 Accuracy(IOU)= 0.42495856
# step) 68747 Accuracy(IOU)= 0.42336616
# step) 68748 Accuracy(IOU)= 0.42203978
# step) 68749 Accuracy(IOU)= 0.42403138
# step) 68750 Accuracy(IOU)= 0.42413506
# step) 68751 Accuracy(IOU)= 0.42563194
# step) 68752 Accuracy(IOU)= 0.4280536
# step) 68753 Accuracy(IOU)= 0.42989492
# step) 68754 Accuracy(IOU)= 0.43127725
# step) 68755 Accuracy(IOU)= 0.4312808
# step) 68756 Accuracy(IOU)= 0.43068308
# step) 68757 Accuracy(IOU)= 0.42992523
# step) 68758 Accuracy(IOU)= 0.42917246
# step) 68759 Accuracy(IOU)= 0.43161654
# step) 68760 Accuracy(IOU)= 0.43041605
# step) 68761 Accuracy(IOU)= 0.43146244
# step) 68762 Accuracy(IOU)= 0.43103302
# step) 68763 Accuracy(IOU)= 0.43035895
# step) 68764 Accuracy(IOU)= 0.4360443
# step) 68765 Accuracy(IOU)= 0.43668038
# step) 68766 Accuracy(IOU)= 0.43668988
# step) 68767 Accuracy(IOU)= 0.43642727
# step) 68768 Accuracy(IOU)= 0.436348
# step) 68769 Accuracy(IOU)= 0.43727726
# step) 68770 Accuracy(IOU)= 0.44038346
# step) 68771 Accuracy(IOU)= 0.44076982
# step) 68772 Accuracy(IOU)= 0.4417964
# step) 68773 Accuracy(IOU)= 0.44075045
# step) 68774 Accuracy(IOU)= 0.44092828
# step) 68775 Accuracy(IOU)= 0.44010222
# step) 68776 Accuracy(IOU)= 0.43990088
# step) 68777 Accuracy(IOU)= 0.43814024
# step) 68778 Accuracy(IOU)= 0.4360475
# step) 68779 Accuracy(IOU)= 0.43337995
# step) 68780 Accuracy(IOU)= 0.43282983
# step) 68781 Accuracy(IOU)= 0.4323954
# step) 68782 Accuracy(IOU)= 0.4344466
# step) 68783 Accuracy(IOU)= 0.43600222
# step) 68784 Accuracy(IOU)= 0.43499267
# step) 68785 Accuracy(IOU)= 0.43405673
# step) 68786 Accuracy(IOU)= 0.4372879
# step) 68787 Accuracy(IOU)= 0.4361688
# step) 68788 Accuracy(IOU)= 0.43547934
# step) 68789 Accuracy(IOU)= 0.43504146
# step) 68790 Accuracy(IOU)= 0.43360364
# step) 68791 Accuracy(IOU)= 0.43141627
# step) 68792 Accuracy(IOU)= 0.43294033
# step) 68793 Accuracy(IOU)= 0.4337331
# step) 68794 Accuracy(IOU)= 0.43582645
# step) 68795 Accuracy(IOU)= 0.4374857
# step) 68796 Accuracy(IOU)= 0.43718997
# step) 68797 Accuracy(IOU)= 0.4356738
# step) 68798 Accuracy(IOU)= 0.4353775
# step) 68799 Accuracy(IOU)= 0.4366591
# step) 68800 Accuracy(IOU)= 0.4397601
# step) 68801 Accuracy(IOU)= 0.44274676
# step) 68802 Accuracy(IOU)= 0.44063038
# step) 68803 Accuracy(IOU)= 0.44153333
# step) 68804 Accuracy(IOU)= 0.442672
# step) 68805 Accuracy(IOU)= 0.442204
# step) 68806 Accuracy(IOU)= 0.44097847
# step) 68807 Accuracy(IOU)= 0.43987587
# step) 68808 Accuracy(IOU)= 0.4377557
# step) 68809 Accuracy(IOU)= 0.4373809
# step) 68810 Accuracy(IOU)= 0.43670523
# step) 68811 Accuracy(IOU)= 0.43498424
# step) 68812 Accuracy(IOU)= 0.4361331
# step) 68813 Accuracy(IOU)= 0.43680412
# step) 68814 Accuracy(IOU)= 0.4359986
# step) 68815 Accuracy(IOU)= 0.43565112
# step) 68816 Accuracy(IOU)= 0.4356386
# step) 68817 Accuracy(IOU)= 0.4335996
# step) 68818 Accuracy(IOU)= 0.43788698
# step) 68819 Accuracy(IOU)= 0.43650112
# step) 68820 Accuracy(IOU)= 0.43476868
# step) 68821 Accuracy(IOU)= 0.4346846
# step) 68822 Accuracy(IOU)= 0.43720686
# step) 68823 Accuracy(IOU)= 0.4367932
# step) 68824 Accuracy(IOU)= 0.4361266
# step) 68825 Accuracy(IOU)= 0.43829116
# step) 68826 Accuracy(IOU)= 0.4393611
# step) 68827 Accuracy(IOU)= 0.4383661
# step) 68828 Accuracy(IOU)= 0.4376452
# step) 68829 Accuracy(IOU)= 0.43454495
# step) 68830 Accuracy(IOU)= 0.43359077
# step) 68831 Accuracy(IOU)= 0.43273556
# step) 68832 Accuracy(IOU)= 0.43253168
# step) 68833 Accuracy(IOU)= 0.4337244
# step) 68834 Accuracy(IOU)= 0.4350563
# step) 68835 Accuracy(IOU)= 0.43567452
# step) 68836 Accuracy(IOU)= 0.43516374
# step) 68837 Accuracy(IOU)= 0.43543404
# step) 68838 Accuracy(IOU)= 0.43654442
# step) 68839 Accuracy(IOU)= 0.4359027
# step) 68840 Accuracy(IOU)= 0.4350311
# step) 68841 Accuracy(IOU)= 0.43495423
# step) 68842 Accuracy(IOU)= 0.4361426
# step) 68843 Accuracy(IOU)= 0.43503636
# step) 68844 Accuracy(IOU)= 0.43505207
# step) 68845 Accuracy(IOU)= 0.4351759
# step) 68846 Accuracy(IOU)= 0.43317074
# step) 68847 Accuracy(IOU)= 0.43537843
# step) 68848 Accuracy(IOU)= 0.43531013
# step) 68849 Accuracy(IOU)= 0.43623623
# step) 68850 Accuracy(IOU)= 0.43684897
# step) 68851 Accuracy(IOU)= 0.43488276
# step) 68852 Accuracy(IOU)= 0.4367437
# step) 68853 Accuracy(IOU)= 0.4372254
# step) 68854 Accuracy(IOU)= 0.43408185
# step) 68855 Accuracy(IOU)= 0.43597606
# step) 68856 Accuracy(IOU)= 0.4336566
# step) 68857 Accuracy(IOU)= 0.43233603
# step) 68858 Accuracy(IOU)= 0.4318083
# step) 68859 Accuracy(IOU)= 0.43165863
# step) 68860 Accuracy(IOU)= 0.42923915
# step) 68861 Accuracy(IOU)= 0.432038
# step) 68862 Accuracy(IOU)= 0.43267962
# step) 68863 Accuracy(IOU)= 0.43104914
# step) 68864 Accuracy(IOU)= 0.4302206
# step) 68865 Accuracy(IOU)= 0.4303351
# step) 68866 Accuracy(IOU)= 0.42991585
# step) 68867 Accuracy(IOU)= 0.4302938
# step) 68868 Accuracy(IOU)= 0.4283697
# step) 68869 Accuracy(IOU)= 0.4282355
# step) 68870 Accuracy(IOU)= 0.43139207
# step) 68871 Accuracy(IOU)= 0.42970866
# step) 68872 Accuracy(IOU)= 0.42905307
# step) 68873 Accuracy(IOU)= 0.43001837
# step) 68874 Accuracy(IOU)= 0.43006256
# step) 68875 Accuracy(IOU)= 0.43044624
# step) 68876 Accuracy(IOU)= 0.42935896
# step) 68877 Accuracy(IOU)= 0.4274458
# step) 68878 Accuracy(IOU)= 0.4272658
# step) 68879 Accuracy(IOU)= 0.4255882
# step) 68880 Accuracy(IOU)= 0.4238484
# step) 68881 Accuracy(IOU)= 0.42510042
# step) 68882 Accuracy(IOU)= 0.42275086
# step) 68883 Accuracy(IOU)= 0.42283097
# step) 68884 Accuracy(IOU)= 0.42288056
# step) 68885 Accuracy(IOU)= 0.4259609
# step) 68886 Accuracy(IOU)= 0.4244294
# step) 68888 Accuracy(IOU)= 0.4236911
# step) 68889 Accuracy(IOU)= 0.42391595
# step) 68890 Accuracy(IOU)= 0.42616048
# step) 68891 Accuracy(IOU)= 0.42550904
# step) 68892 Accuracy(IOU)= 0.4256098
# step) 68893 Accuracy(IOU)= 0.42807886
# step) 68894 Accuracy(IOU)= 0.4262121
# step) 68895 Accuracy(IOU)= 0.42437
# step) 68896 Accuracy(IOU)= 0.42634797
# step) 68897 Accuracy(IOU)= 0.42616472
# step) 68898 Accuracy(IOU)= 0.42673182
# step) 68899 Accuracy(IOU)= 0.4292761
# step) 68900 Accuracy(IOU)= 0.42712107
# step) 68901 Accuracy(IOU)= 0.42694852
# step) 68902 Accuracy(IOU)= 0.42636678
# step) 68903 Accuracy(IOU)= 0.42688277
# step) 68904 Accuracy(IOU)= 0.4247587
# step) 68905 Accuracy(IOU)= 0.4246892
# step) 68906 Accuracy(IOU)= 0.42302203
# step) 68907 Accuracy(IOU)= 0.42342624
# step) 68908 Accuracy(IOU)= 0.4224651
# step) 68909 Accuracy(IOU)= 0.42368507
# step) 68910 Accuracy(IOU)= 0.42215133
# step) 68911 Accuracy(IOU)= 0.42099732
# step) 68912 Accuracy(IOU)= 0.42403725
# step) 68913 Accuracy(IOU)= 0.42343968
# step) 68914 Accuracy(IOU)= 0.42645052
# step) 68915 Accuracy(IOU)= 0.4270645
# step) 68916 Accuracy(IOU)= 0.42770877
# step) 68917 Accuracy(IOU)= 0.42884243
# step) 68918 Accuracy(IOU)= 0.42848054
# step) 68919 Accuracy(IOU)= 0.42717367
# step) 68920 Accuracy(IOU)= 0.42575005
# step) 68921 Accuracy(IOU)= 0.4251961
# step) 68922 Accuracy(IOU)= 0.4248889
# step) 68923 Accuracy(IOU)= 0.42225155
# step) 68924 Accuracy(IOU)= 0.4249413
# step) 68925 Accuracy(IOU)= 0.42468962
# step) 68926 Accuracy(IOU)= 0.4246107
# step) 68927 Accuracy(IOU)= 0.42316425
# step) 68928 Accuracy(IOU)= 0.4219313
# step) 68929 Accuracy(IOU)= 0.42176116
# step) 68930 Accuracy(IOU)= 0.42152137
# step) 68931 Accuracy(IOU)= 0.42173216
# step) 68932 Accuracy(IOU)= 0.42190126
# step) 68933 Accuracy(IOU)= 0.42231095
# step) 68934 Accuracy(IOU)= 0.4221962
# step) 68935 Accuracy(IOU)= 0.42261502
# step) 68936 Accuracy(IOU)= 0.4216015
# step) 68937 Accuracy(IOU)= 0.42605793
# step) 68938 Accuracy(IOU)= 0.4294742
# step) 68939 Accuracy(IOU)= 0.42880964
# step) 68940 Accuracy(IOU)= 0.4272823
# step) 68941 Accuracy(IOU)= 0.4279128
# step) 68942 Accuracy(IOU)= 0.42943674
# step) 68943 Accuracy(IOU)= 0.4305046
# step) 68944 Accuracy(IOU)= 0.43129012
# step) 68945 Accuracy(IOU)= 0.4311393
# step) 68946 Accuracy(IOU)= 0.43059742
# step) 68947 Accuracy(IOU)= 0.43111515
# step) 68948 Accuracy(IOU)= 0.43032646
# step) 68949 Accuracy(IOU)= 0.42907158
# step) 68950 Accuracy(IOU)= 0.42769796
# step) 68951 Accuracy(IOU)= 0.42898706
# step) 68952 Accuracy(IOU)= 0.42744243
# step) 68953 Accuracy(IOU)= 0.4288631
# step) 68954 Accuracy(IOU)= 0.43010744
# step) 68955 Accuracy(IOU)= 0.42915773
# step) 68956 Accuracy(IOU)= 0.4289616
# step) 68957 Accuracy(IOU)= 0.42877463
# step) 68958 Accuracy(IOU)= 0.43069175
# step) 68959 Accuracy(IOU)= 0.43084747
# step) 68960 Accuracy(IOU)= 0.43113732
# step) 68961 Accuracy(IOU)= 0.43252867
# step) 68962 Accuracy(IOU)= 0.43203008
# step) 68963 Accuracy(IOU)= 0.43262053
# step) 68964 Accuracy(IOU)= 0.4322904
# step) 68965 Accuracy(IOU)= 0.43152583
# step) 68966 Accuracy(IOU)= 0.4289719
# step) 68967 Accuracy(IOU)= 0.42644122
# step) 68968 Accuracy(IOU)= 0.42540777
# step) 68969 Accuracy(IOU)= 0.42488402
# step) 68970 Accuracy(IOU)= 0.4263049
# step) 68971 Accuracy(IOU)= 0.42618483
# step) 68972 Accuracy(IOU)= 0.4261723
# step) 68973 Accuracy(IOU)= 0.42562103
# step) 68974 Accuracy(IOU)= 0.42510033
# step) 68975 Accuracy(IOU)= 0.42187297
# step) 68976 Accuracy(IOU)= 0.42039767
# step) 68977 Accuracy(IOU)= 0.41883284
# step) 68978 Accuracy(IOU)= 0.42028415
# step) 68979 Accuracy(IOU)= 0.4202084
# step) 68980 Accuracy(IOU)= 0.41873935
# step) 68981 Accuracy(IOU)= 0.4181329
# step) 68982 Accuracy(IOU)= 0.41710186
# step) 68983 Accuracy(IOU)= 0.41680962
# step) 68984 Accuracy(IOU)= 0.4162567
# step) 68985 Accuracy(IOU)= 0.41440272
# step) 68986 Accuracy(IOU)= 0.41396463
# step) 68987 Accuracy(IOU)= 0.41622534
# step) 68988 Accuracy(IOU)= 0.4157712
# step) 68989 Accuracy(IOU)= 0.41544747
# step) 68990 Accuracy(IOU)= 0.4137818
# step) 68991 Accuracy(IOU)= 0.41301936
# step) 68992 Accuracy(IOU)= 0.4124901
# step) 68993 Accuracy(IOU)= 0.4183567
# step) 68994 Accuracy(IOU)= 0.41925403
# step) 68995 Accuracy(IOU)= 0.42047593
# step) 68996 Accuracy(IOU)= 0.41986847
# step) 68997 Accuracy(IOU)= 0.4174158
# step) 68998 Accuracy(IOU)= 0.41790465
# step) 68999 Accuracy(IOU)= 0.41771522
# save model
# step) 69000 Accuracy(IOU)= 0.41605946
# step) 69001 Accuracy(IOU)= 0.41508648
# step) 69002 Accuracy(IOU)= 0.41675457
# step) 69003 Accuracy(IOU)= 0.41698778
# step) 69004 Accuracy(IOU)= 0.41777208
# step) 69005 Accuracy(IOU)= 0.41731542
# step) 69006 Accuracy(IOU)= 0.41760147
# step) 69007 Accuracy(IOU)= 0.41659248
# step) 69008 Accuracy(IOU)= 0.41682553
# step) 69009 Accuracy(IOU)= 0.41682395
# step) 69010 Accuracy(IOU)= 0.41431186
# step) 69011 Accuracy(IOU)= 0.42016357
# step) 69012 Accuracy(IOU)= 0.4212975
# step) 69013 Accuracy(IOU)= 0.4222707
# step) 69014 Accuracy(IOU)= 0.42132297
# step) 69015 Accuracy(IOU)= 0.42305216
# step) 69016 Accuracy(IOU)= 0.4226871
# step) 69017 Accuracy(IOU)= 0.4211922
# step) 69018 Accuracy(IOU)= 0.42285517
# step) 69019 Accuracy(IOU)= 0.42443877
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 11
#       7 predictor.set_image(image) # apply SAM image encoder to the image
#       9 # prompt encoding
# ---> 11 mask_input, unnorm_coords, labels, unnorm_box = predictor._prep_prompts(input_point, input_label, box=None, mask_logits=None, normalize_coords=True)
#      12 sparse_embeddings, dense_embeddings = predictor.model.sam_prompt_encoder(points=(unnorm_coords, labels),boxes=None,masks=None,)
#      14 # mask decoder
#
# File D:\code\PycharmProjects\sam2-main\sam2\sam2_image_predictor.py:314, in SAM2ImagePredictor._prep_prompts(self, point_coords, point_labels, box, mask_logits, normalize_coords, img_idx)
#     310 if point_coords is not None:
#     311     assert (
#     312         point_labels is not None
#     313     ), "point_labels must be supplied if point_coords is supplied."
# --> 314     point_coords = torch.as_tensor(
#     315         point_coords, dtype=torch.float, device=self.device
#     316     )
#     317     unnorm_coords = self._transforms.transform_coords(
#     318         point_coords, normalize=normalize_coords, orig_hw=self._orig_hw[img_idx]
#     319     )
#     320     labels = torch.as_tensor(point_labels, dtype=torch.int, device=self.device)
#
# KeyboardInterrupt:

# %% [markdown]
# ## 调用微调后的模型

# %%
import numpy as np
import torch
import cv2
from sam2.build_sam import build_sam2
from sam2.sam2_image_predictor import SAM2ImagePredictor

# use bfloat16 for the entire script (memory efficient)
torch.autocast(device_type="cuda", dtype=torch.bfloat16).__enter__()

# %%
# Load image

image_path = r"./EarthVQA/Test/images_png/4191.png" # path to image
mask_path = r"./EarthVQA/Test/masks_png/4191.png" # path to mask, the mask will define the image region to segment

def read_image(image_path, mask_path): # read and resize image and mask
        img = cv2.imread(image_path)[...,::-1]  # read image as rgb
        mask = cv2.imread(mask_path,0) # mask of the region we want to segment

        # Resize image to maximum size of 1024

        r = np.min([1024 / img.shape[1], 1024 / img.shape[0]])
        img = cv2.resize(img, (int(img.shape[1] * r), int(img.shape[0] * r)))
        mask = cv2.resize(mask, (int(mask.shape[1] * r), int(mask.shape[0] * r)),interpolation=cv2.INTER_NEAREST)
        return img, mask
image,mask = read_image(image_path, mask_path)
num_samples = 30 # number of points/segment to sample
def get_points(mask,num_points): # Sample points inside the input mask
        points=[]
        for i in range(num_points):
            coords = np.argwhere(mask > 0)
            yx = np.array(coords[np.random.randint(len(coords))])
            points.append([[yx[1], yx[0]]])
        return np.array(points)
input_points = get_points(mask,num_samples)
# read image and sample points

# %%
# Load model
sam2_checkpoint = "./checkpoints/sam2.1_hiera_large.pt" # "sam2_hiera_large.pt"
model_cfg = "configs/sam2.1/sam2.1_hiera_l.yaml" # "sam2_hiera_l.yaml"
sam2_model = build_sam2(model_cfg, sam2_checkpoint, device="cuda")

# Build net and load weights
predictor = SAM2ImagePredictor(sam2_model)
predictor.model.load_state_dict(torch.load("model.torch"))
# Out:
# <All keys matched successfully>

# %%
# predict mask

with torch.no_grad():
        predictor.set_image(image)
        masks, scores, logits = predictor.predict(
            point_coords=input_points,
            point_labels=np.ones([input_points.shape[0],1])
        )

# Short predicted masks from high to low score

masks=masks[:,0].astype(bool)
shorted_masks = masks[np.argsort(scores[:,0])][::-1].astype(bool)

# Stitch predicted mask into one segmentation mask

seg_map = np.zeros_like(shorted_masks[0],dtype=np.uint8)
occupancy_mask = np.zeros_like(shorted_masks[0],dtype=bool)
for i in range(shorted_masks.shape[0]):
    mask = shorted_masks[i]
    if (mask*occupancy_mask).sum()/mask.sum()>0.15: continue
    mask[occupancy_mask]=0
    seg_map[mask]=i+1
    occupancy_mask[mask]=1

# create colored annotation map
height, width = seg_map.shape

# Create an empty RGB image for the colored annotation
rgb_image = np.zeros((seg_map.shape[0], seg_map.shape[1], 3), dtype=np.uint8)
for id_class in range(1,seg_map.max()+1):
    rgb_image[seg_map == id_class] = [np.random.randint(255), np.random.randint(255), np.random.randint(255)]

# %%
# save and display

cv2.imwrite("annotation.png",rgb_image)
cv2.imwrite("mix.png",(rgb_image/2+image/2).astype(np.uint8))

cv2.imshow("annotation",rgb_image)
cv2.imshow("mix",(rgb_image/2+image/2).astype(np.uint8))
cv2.imshow("image",image)
